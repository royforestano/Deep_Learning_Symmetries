# %% [markdown]
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/royforestano/Deep_Learning_Symmetries/blob/main/sym_u_and_su_tutorial.ipynb)

# %% [markdown]
# # Discovering Sparse Representations of Lie Groups with Machine Learning - Tutorial

# %% [markdown]
# Author: Roy Forestano
#
# Date of Completion: 18 February 2023
#
# Connected to the paper on: Discovering Sparse Representations of Lie Groups with Machine Learning (arXiv:2302.05383: https://arxiv.org/abs/2302.05383)
#
# Given a dataset with dimension $N$, a neural network can be utilized to modify a random state of generators and structure constants to reproduce the proper entries corresponding to a given group, e.g. SO(N). The model takes in an array of the desired number of generators $N_{g}$ as $N \times N$ matrices and an array of the structure constants with shape $N_{brackets} \times N_{g}$. The model begins by looping over the generators applying a sequential layer to each. The second part loops over the rows of the structure constant array applying a sequential layer to each, which is a generalized modification to the code for a paper on deep learning symmetries [(Forestano et al.)](https://arxiv.org/abs/2301.05638). The model modifies these arrays to produce the desired generators and structure constants with an interconnected loss function, which now minimizes the dispersion between entries. This allows for a more simple visual verification of a group structure and its algebra by enforcing the resulting elements to be in a sparse representation, which may or may not be the canonical form.

# %% [markdown]
# ## Useful Resources

# %% [markdown]
# 1. The Quaternions and the Spaces S3, SU(2), SO(3), RP3: https://www.cis.upenn.edu/~cis5150/gma-v2-chap9.pdf
# 2. Charts on SO(3): https://en.wikipedia.org/wiki/Charts_on_SO(3)
# 3. Lie Groups as Manifolds SU(2) and Three sphere: http://mf23.web.rice.edu/LA_2_v1.4%20Lie%20groups%20as%20manifolds;%20su(2)%20and%20S3.pdf
# 4. Discrete Group: https://en.wikipedia.org/wiki/Discrete_group
# 5. Torch Complex: https://pytorch.org/docs/stable/complex_numbers.html
# 6. Data types: https://numpy.org/doc/stable/user/basics.types.html
# 7. Special Unitary Group: https://en.wikipedia.org/wiki/Special_unitary_group
# 8. Pauli Matrices and SU(2): https://en.wikipedia.org/wiki/Pauli_matrices
# 9. Gell-Mann Matrices and SU(3): https://en.wikipedia.org/wiki/Gell-Mann_matrices
# 10. Custom Activation for Complex Numbers: https://github.com/pytorch/pytorch/issues/47052
# 11. Complex Activation (Holomorphic Functions, e.g. Sigmoid): https://discuss.pytorch.org/t/complex-valued-neural-network/117090
# 12. Holomorphic Functions: https://en.wikipedia.org/wiki/Holomorphic_function
# 13. Special Unitary Groups: https://en.wikipedia.org/wiki/Special_unitary_group
# 14. ComplexPyTorch: https://github.com/wavefrontshaping/complexPyTorch
# 15. Sigmoid Activation Function: https://en.wikipedia.org/wiki/Sigmoid_function

# %% [markdown]
# ## Loss Function Description

# %% [markdown]
# There are three components to the loss function. Note $|G| = n_{gen}$.
#
# 1. ${\bf Invariance }$
#  $$\mathcal{L}_{inv} = \frac{a_{inv}}{ \epsilon^2} \sum_{j=1}^{n_{gen}} \left\{ \sum_{i=1}^{N} \left[ \phi \left[ (I+\epsilon W_j) \vec{x}_i \right] - \phi\left(\vec{x}_i \right) \right]^2 \right\}$$
# where we will use $\phi \equiv torch.norm$ here ($L^2$ norm which includes imaginary numbers), i.e.,
# $$ \phi(\vec{x}) = \sqrt{\sum_{i=1}^{n_{dim}} |x_i|^2}$$
#
#
# 2. ${\bf Normalization}$
#  $$\mathcal{L}_{norm} = a_{norm}  \sum_{i=1}^{n_{gen}} \left[\text{Tr}(W_i W_i^\dagger) - 2\right]^2$$
#  Note that  $\text{Tr}(W_i W_i^T)$ is equivalent to squaring all the elements of an array, or performing numpy multiplication of arrays in python.
#
# 3. ${\bf Orthogonality}$
#  $$\mathcal{L}_{orth} = a_{orth} \sum_{i, j = 1, i<j}^{n_{gen}} \left| \text{Tr}(W_i W_j) \right|^2$$
#
# 4. ${\bf Hermicity}$
#  $$ \mathcal{L}_{herm} = a_{unit}\sum_{k=0}^{n_{gen}} \left[ \sum_{i,j =1}^{N} \left| W_k - W_k^\dagger \right|_{ij} \right]^2 $$
#
# 5. ${ \bf Closure}$
#  $$\mathcal{L}_{clos} = a_{clos}  \sum_{i, j = 1, i<j}^{n_{gen}} \text{Tr}(C_{[ij]} C_{[ij]}^T)^2$$
#  where
#  $$C_{[ij]} = [W_i, W_j] - \sum_{k=1}^{n_{gen}} a_{[ij]k} W_k$$
#
# 6. ${ \bf Sparsity}$
#  $$\mathcal{L}_{sp} = a_{sp}   \sum_{i=0}^{n_{gen}} \sum_{l,m,n,p=0,\\ l \neq n, m \neq p}^{n_{dim}}  \left[ W_i^{lm} W_i^{np} \right]^2$$
#
# and therefore, our loss becomes
# $$\mathcal{L} = \mathcal{L}_{inv} + \mathcal{L}_{norm} + \mathcal{L}_{orth} + \mathcal{L}_{clos} + \mathcal{L}_{sp}$$

# %%
#!pip install torch

# %% [markdown]
# ## Imports

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
# %matplotlib inline
import scipy
import os
import copy
from tqdm import tqdm
from time import time

import torch
from torch import nn
from torch.utils.data import DataLoader
from torch.utils.data import Dataset
from torchvision import datasets
from torch import linalg
from torchvision.transforms import ToTensor
from complexPyTorch.complexFunctions import complex_relu
torch.set_default_dtype(torch.float64)

plt.rcParams["font.family"] = 'sans-serif'
np.set_printoptions(formatter={'float_kind':'{:f}'.format}) 

# Get cpu or gpu device for training.
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using {device} device")
# Out:
# Using cpu device

# %% [markdown]
# ## Set Initial Conditions, Model, Optimizer, Loss, and Training Function

# %%
# Define oracles and useful definitions
def oracle_norm(data): # L^2 Norm (includes imaginary) on X: sqrt(sum(|x_i|^2))
    return torch.norm(torch.abs(data),dim=1)

def oracle_complex_norm(data): # L^2 Norm (includes imaginary) on X: sqrt(sum(|x_i|^2))
    return linalg.vector_norm(data,dim=1)
    #return torch.sum((data*data.conj()).abs(),dim=1)

def G2(data):
    return (c_tensor*torch.einsum('ij,ik,il->ijkl',data[:n//3],data[n//3:2*n//3],data[2*n//3:])).sum(dim=[1,2,3])

def bracket(M,N):
    return M@N - N@M

# %% [markdown]
# Define a custom complex activation function (as a Module subclass using nn.Module)

# %%
# Define a custom complex activation function (nn.Module)
class complex_activation(nn.Module):
    def forward(self, x):
        return nn.ReLU()(x.real) + 1.j * nn.ReLU()(x.imag)

# %% [markdown]
# Define model

# %%
# Define model
class find_generators(nn.Module):
    def __init__(self,n_dim,n_gen,n_com):
        super(find_generators,self).__init__()
       
        G = [ nn.Sequential( nn.Linear(in_features = n_dim*n_dim, out_features = n_dim*n_dim, bias = True, dtype=torch.cfloat), #torch.complex128
                             complex_activation(),
                             nn.Linear(in_features = n_dim*n_dim, out_features = n_dim*n_dim, bias = True, dtype=torch.cfloat),
                             complex_activation(),
                             nn.Linear(in_features = n_dim*n_dim, out_features = n_dim*n_dim, bias = True, dtype=torch.cfloat) )  for _ in range(n_gen)]
        
        
        self.gens = nn.ModuleList(G)
        
        if include_sc:
            C = [ nn.Sequential( nn.Linear(in_features = n_gen, out_features = n_gen, bias = True, dtype=torch.cfloat),
                             complex_activation(),
                             nn.Linear(in_features = n_gen, out_features = n_gen, bias = True, dtype=torch.cfloat),
                             complex_activation(),
                             nn.Linear(in_features = n_gen, out_features = n_gen, bias = True, dtype=torch.cfloat) ) for _ in range(n_com) ]
        
        
            self.struct_const = nn.ModuleList(C)
        
        self.n_gen = n_gen
        self.n_dim = n_dim
        self.n_com = n_com

    def forward(self, x, c):
        generators = []
        for i in range(self.n_gen):
            generators.append( ( self.gens[i](x[i].flatten()) ).reshape(self.n_dim,self.n_dim)  )
        
        structure_constants = torch.zeros((self.n_com,self.n_gen),dtype=torch.cfloat)
        
        if include_sc:
            structure_constants = torch.empty((self.n_com,self.n_gen),dtype=torch.cfloat)
            for i in range(self.n_com):
                structure_constants[i,:] = ( self.struct_const[i](c[i].flatten()) ).reshape(1,self.n_gen)

        return generators , structure_constants

# %% [markdown]
# Define the loss function

# %%
# define loss function
def loss_fn(data,
            generators,
            struc_const,
            eps,
            ainv=1., anorm=1., aorth=1., aclos=1., asp = 1. ):

    upper_elements = int(n_dim*(n_dim-1)/2)
    lossi = 0.
    lossn = 0.
    losso = 0.
    lossc = 0.
    losssp = 0.
    comm_index = 0
    struc_const = struc_const.to(device)
    indcs_upper = np.triu_indices(n_dim)
    indices_upper_offset = np.triu_indices_from(generators[0], k=1)
    indcs_lower = np.tril_indices(n_dim)
    indices_lower_offset = np.tril_indices_from(generators[0], k=1)
    identity = torch.eye(generators[0].shape[0],dtype=torch.cfloat).to(device)
    
    for i,G in enumerate(generators): 
        transform = torch.transpose((identity + 1.j*eps*G)@torch.transpose(data,dim0=1,dim1=0), dim0=1, dim1=0 )
        lossi  += torch.mean( ( oracle(transform) - oracle(data) )**2)**2/ eps**2
        #lossi  += torch.mean( ( G2(transform) - G2(data) ).abs()**2 ) / eps**2
        lossn  += ((torch.view_as_real(G).flatten()**2).sum() - 2)**2 #torch.conj(G)
        lossn  += (G-G.conj().T).abs().sum()**2

        losssp += (torch.outer(G.real.flatten(),G.real.flatten())**2 - torch.eye(G.real.flatten().shape[0])*torch.outer(G.real.flatten(),G.real.flatten())**2).sum()**2
        losssp += (torch.outer(G.imag.flatten(),G.imag.flatten())**2 - torch.eye(G.real.flatten().shape[0])*torch.outer(G.imag.flatten(),G.imag.flatten())**2).sum()**2
        
        losssp += (torch.outer(G[indcs_upper].abs(),G[indcs_upper].abs())**2 - torch.eye(G[indcs_upper].shape[0],dtype=torch.cfloat).abs()*torch.outer(G[indcs_upper].abs(),G[indcs_upper].abs())**2).sum()**2
        losssp += (torch.outer(G[indcs_lower].abs(),G[indcs_lower].abs())**2 - torch.eye(G[indcs_lower].shape[0],dtype=torch.cfloat).abs()*torch.outer(G[indcs_lower].abs(),G[indcs_lower].abs())**2).sum()**2
        losssp += (torch.outer(G.real.flatten(),G.imag.flatten())**2).sum()**2
        
        losso += ((G@G).trace().abs()-2)**2
        for j, H in enumerate(generators):
            if i < j:
                losso += (G@H).trace().abs()**2
                losso += (G*H).sum().abs()**2

                C1 = torch.view_as_real(bracket(G,H))
                C2 = 0
                for k,K in enumerate(generators):
                    C2 += struc_const[comm_index,k]*K
                C = C1-torch.view_as_real(C2)
                lossc += torch.sum(C**2)**2
                comm_index +=1
    
    components = [ ainv*lossi,  
                anorm*lossn,  
                aorth*losso,  
                aclos*lossc,
                asp*losssp ]

    L = ainv*lossi + anorm*lossn + aorth*losso + aclos*lossc + asp*losssp
    return  L.to(device), components

# %% [markdown]
# Define the training function

# %%
# Define the training function
def train(initial_matrices, 
          initial_struc_const,  
          data, 
          model, 
          loss_fn, 
          epochs, 
          optimizer, 
          eps):
    
    history = {'train_loss': [],
               'components_loss':[]} 
    
    best_val_loss = float('inf') #torch.inf #float('inf')
    start = time()
    
    ainv  = 1.
    anorm = 1.
    aorth = 10.
    aclos = 0.
    if include_sc:
        aclos = 10.
    asp   = 1e-1

    
    X = initial_matrices.to(device)
    Y = initial_struc_const.to(device)
    size = X.shape[0]
    
    for i in range(epochs):
        train_loss = 0.
        model.train()
        gens, struc_const = model(X,Y)
        
        loss, comp_loss = loss_fn( data         = data,
                        generators   = gens,
                        struc_const  = struc_const,
                        eps          = eps,
                        ainv         = ainv,
                        anorm        = anorm,
                        aorth        = aorth,
                        aclos        = aclos,
                        asp          = asp )

        # Backpropagation
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        train_loss += loss.data.item()
        comp_loss_for_epoch = []
        
        for j in range(len(comp_loss)):
            if torch.is_tensor(comp_loss[j]):
                comp_loss_for_epoch.append(comp_loss[j].data.item())
            else:
                comp_loss_for_epoch.append(comp_loss[j])
            
        history['train_loss'].append(train_loss)
        history['components_loss'].append(comp_loss_for_epoch)
        
        if i%1==0:
            print(f"Epoch {i+1}   |  Train Loss: {train_loss}",end='\r') #{train_loss:>8f}
        if i==epochs-1:
            print(f"Epoch {i+1}   |  Train Loss: {train_loss}")
    
        if train_loss*1e25 < 1:
            print()
            print('Reached Near Machine Zero')
            break
        
        if train_loss < best_val_loss:
            best_val_loss = train_loss
            best_model_wts = copy.deepcopy(model.state_dict())
            best_model = copy.deepcopy(model)
            torch.save(model.state_dict(),'best_complex_U6.pth')

    model = best_model   
    end = time()
    total_time = end-start
    print(f'Total Time: {total_time:>.8f}')
    print("Complete.")
    return {'history': history}

# %% [markdown]
# ## Set Hyperparameters and Train the Model

# %%
torch.manual_seed(0)
n       = 300 # sample size
n_dim   = 6   # dimension
n_gen   = 36   # n_gen_full = int(n_dim*(n_dim-1)/2) formula for full algebra
n_com = int(n_gen*(n_gen-1)/2) # N_g choose 2 of these
include_sc = False

data    = torch.randn(n,n_dim,dtype=torch.cfloat).to(device) #Can also use torch.complex128 # Ceate n number of n-dim vectors
initialize_matrices = torch.stack([ torch.randn(n_dim,n_dim,dtype=torch.cfloat) for i in range(n_gen) ], dim=0).to(device)
initialize_struc_const = torch.randn(n_com,n_gen,dtype=torch.cfloat).to(device)

oracle = oracle_complex_norm
eps   = 1e-3

model = find_generators(n_dim,n_gen,n_com).to(device)

if n_dim==2:
    lr=7e-2
elif n_dim==3:
    lr = 1e-2  
elif n_dim==4:
    lr = 5e-3
elif n_dim>=5:
    lr = 1e-3
    
optimizer = torch.optim.Adam(model.parameters(), lr=lr)

# %% [markdown]
# ## Train the Model

# %%
if n_dim==2:
    epochs = 500
elif n_dim>=3:
    epochs = 2000
    
training = train( initial_matrices    = initialize_matrices, 
                  initial_struc_const = initialize_struc_const,  
                  data                = data,
                  model               = model, 
                  loss_fn             = loss_fn,
                  epochs              = epochs,
                  optimizer           = optimizer,
                  eps                 = eps  )
# Out:
# Epoch 2000   |  Train Loss: 11.586699633913085
# Total Time: 2551.14702892
# Complete.

# %%
#model.load_state_dict(torch.load('best_complex_U6.pth',map_location=torch.device('cpu')))

# %% [markdown]
# ## Visualize the History of Training Loss

# %%
if n_gen>1:
    train_loss = np.array(training['history']['train_loss'])
    comp_loss = np.array(training['history']['components_loss'])
else:
    train_loss = np.array(training['history']['train_loss'])
    comp_loss = np.empty( ( train_loss.shape[0],len(training['history']['components_loss']) ) )
    for i,comp in enumerate(training['history']['components_loss']):
        for j,term in enumerate(comp):
            if torch.is_tensor(term) and term.requires_grad:
                comp_loss[i,j] = term.detach().numpy()
            else:
                comp_loss[i,j] = term

# %%
N=train_loss.shape[0]
plt.figure(figsize=(6,4)) #, dpi=100)
plt.plot( train_loss[:N], linewidth=1, linestyle='-',  color = 'r', label='Total')
plt.plot(comp_loss[:N,0], linewidth=1, linestyle=':',  color='b',   label='Invariance')
plt.plot(comp_loss[:N,1], linewidth=1, linestyle='--', color='g',   label='Normalization')
plt.plot(comp_loss[:N,2], linewidth=1, linestyle='-.', color='magenta', label='Orthogonality')
plt.plot(comp_loss[:N,3], linewidth=1, linestyle='-.', color='cyan', label='Closure')
plt.plot(comp_loss[:N,4], linewidth=1, linestyle='--', color='black', label='Sparsity')
plt.legend()

plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.yscale('log')
plt.title('Components of Loss')

plt.show()

# %% [markdown]
# ## Extract Results

# %%
model.eval()

with torch.no_grad():
    gens_pred, struc_pred = model(initialize_matrices,initialize_struc_const)

# %% [markdown]
# # Visualize Results

# %% [markdown]
# ## View the Resulting Generator(s)

# %%
rows=6
cols=2*6
figsize=(40,12)

# Create labels for matrix rows and columns
ticks_gen_im =[]
ticks_gen_im_label = []
for i in range(n_dim):
    ticks_gen_im.append(i)
    ticks_gen_im_label.append(str(i+1))

fig,axes = plt.subplots(rows,cols,figsize=figsize)
for i,GEN in enumerate(gens_pred):
    plt.subplot(rows,cols,i*2+1)
    #if n_gen<10:
    #    print(f'Generator {i+1}: \n {GEN} \n')
    im = plt.imshow(GEN.real.detach().numpy(), cmap='RdBu', vmin=-np.sqrt(2), vmax=np.sqrt(2)) # use ax_GEN[0] with axes
    if i<9:
        plt.ylabel(r'$\mathbb{J}$'+f'$_{i+1}$',fontsize=20)
    else:
        number = str(i+1)
        plt.ylabel(r'$\mathbb{J}$'+f'$_{number[0]}$'+f'$_{number[1]}$',fontsize=20)
    if i*2<cols:
        plt.title('$\mathfrak{R}$',fontsize=20)
    if rows>1:
        if i*2>=(rows-1)*cols:
            plt.xticks(ticks=ticks_gen_im, labels=ticks_gen_im_label)
        else:
            plt.xticks([])
    else:
        plt.xticks(ticks=ticks_gen_im, labels=ticks_gen_im_label)
            
    if i%(cols/2)==0:
        plt.yticks(ticks=ticks_gen_im, labels=ticks_gen_im_label)
    else:
        plt.yticks([])
            
            
    plt.subplot(rows,cols,i*2+2)
    im = plt.imshow(GEN.imag.detach().numpy(), cmap='RdBu', vmin=-np.sqrt(2), vmax=np.sqrt(2))
    if i*2<cols:
        plt.title('$\mathfrak{I}$',fontsize=20)
#         if n_gen<7:
#             det = np.linalg.det(np.eye(GEN.shape[0]) + eps * GEN.detach().numpy()) #ax_GEN[1]
#             plt.title(f'det = {det}')
#         plt.axis('off')
    if rows>1:
        if i*2>=(rows-1)*cols:
            plt.xticks(ticks=ticks_gen_im, labels=ticks_gen_im_label)
        else:   #(rows*cols/2-rows-1):
            plt.xticks([])
    else:
        plt.xticks(ticks=ticks_gen_im, labels=ticks_gen_im_label)
    plt.yticks([])

if (len(gens_pred)%2==1 and n_dim%2==0) or (len(gens_pred)%2==0 and n_dim%2==1):
    plt.subplot(rows,cols,len(gens_pred)*2+1)
    plt.axis('off')
    plt.subplot(rows,cols,len(gens_pred)*2+2)
    plt.axis('off')
            
    plt.subplots_adjust(right=0.8)
cbar = fig.colorbar(im,ax=axes.ravel().tolist(), ticks=[-np.sqrt(2), 0, np.sqrt(2)])
cbar.ax.set_yticklabels(['-$\sqrt{2}$', '0', '$\sqrt{2}$']) 
#plt.savefig('U6_6_36_00.png',bbox_inches='tight')
#plt.savefig('SU6_6_35_00.png',bbox_inches='tight')
# Out:
# [Text(1, -1.4142135623730951, '-$\\sqrt{2}$'),
#  Text(1, 0.0, '0'),
#  Text(1, 1.4142135623730951, '$\\sqrt{2}$')]

# %% [markdown]
# ## View the Resulting Structure Constants (for $n_{gen}>1$)

# %%
if include_sc and n_gen>1:
    
    figsize=(12,30)
    
    if n_gen==3:
        X = torch.tensor(struc_pred.numpy())
        struc_cyclic = X
        struc_cyclic[1] = -X[1]
        
    commutator_labels = []
    if n_com==3:
        # Make the commutations cyclic for 3 generators
        for i in range(n_gen):
             for j in range(n_gen):
                    if i<j:
                        if (j-i)==2:
                            commutator_labels.append(str(j+1)+str(i+1))
                        else:
                            commutator_labels.append(str(i+1)+str(j+1))
    else:
        for i in range(n_gen):
            for j in range(n_gen):
                if i<j:
                    if n_gen>9:
                        if i<9 and j<9:
                            commutator_labels.append(str(0)+str(i+1)+str(0)+str(j+1))
                        elif i<9 and j>=9:
                            commutator_labels.append(str(0)+str(i+1)+str(j+1))
                        else:
                            commutator_labels.append(str(i+1)+str(j+1))
                    else:
                        commutator_labels.append(str(i+1)+str(j+1))
        
    ticks_com = []
    for i in range(n_com):
        ticks_com.append(i)

    ticks_gen = []
    generator_labels = []
    for i in range(n_gen):
        ticks_gen.append(i)
        generator_labels.append(str(i+1))
    
    fig,axes = plt.subplots(1,2,figsize=figsize)
    if n_com==3:
        plt.subplot(1,2,1)
        plt.imshow(struc_cyclic.real.detach().numpy(), cmap='RdBu', vmin=-2.,vmax=2.)#norm=mpl.colors.CenteredNorm())
        plt.xticks(ticks=ticks_gen,labels=generator_labels)
        plt.xlabel('$\mathbb{J}_\gamma$',fontsize=20)
        plt.yticks(ticks=ticks_com,labels=commutator_labels)
        plt.ylabel(r'$ [\mathbb{J}_\alpha$,$\mathbb{J}_\beta ] $',fontsize=20)
        plt.title(r'$\mathfrak{R}(a_{[\alpha\beta]\gamma})$',fontsize=20)
        
        plt.subplot(1,2,2)
        im = plt.imshow(struc_cyclic.imag.detach().numpy(), cmap='RdBu', vmin=-2.,vmax=2.)
        plt.xticks(ticks=ticks_gen,labels=generator_labels)
        plt.xlabel('$\mathbb{J}_\gamma$',fontsize=20)
        plt.yticks([])
        plt.title(r'$\mathfrak{I}(a_{[\alpha\beta]\gamma})$',fontsize=20)
        
    else:
        plt.subplot(1,2,1)
        plt.imshow(struc_pred.real.detach().numpy(), cmap='RdBu', vmin=-2.,vmax=2.)#norm=mpl.colors.CenteredNorm())
        plt.xticks(ticks=ticks_gen,labels=generator_labels)
        plt.xlabel('$\mathbb{J}_\gamma$',fontsize=20)
        plt.yticks(ticks=ticks_com,labels=commutator_labels)
        plt.ylabel(r'$ [\mathbb{J}_\alpha$,$\mathbb{J}_\beta ] $',fontsize=20)
        plt.title(r'$\mathfrak{R}(a_{[\alpha\beta]\gamma})$',fontsize=20)
        
        plt.subplot(1,2,2)
        im = plt.imshow(struc_pred.imag.detach().numpy(), cmap='RdBu', vmin=-2.,vmax=2.)
        plt.xticks(ticks=ticks_gen,labels=generator_labels)
        plt.xlabel('$\mathbb{J}_\gamma$',fontsize=20)
        plt.yticks([])
        plt.title(r'$\mathfrak{I}(a_{[\alpha\beta]\gamma})$',fontsize=20)
        
    plt.colorbar(im, ax=axes.ravel().tolist())
    
    # add grid lines
    # for i in range(n_gen-1):
    #     plt.axvline(x=1/2+i, linewidth=1, color ='black')
    # for i in range(n_com-1):
    #     plt.axhline(y=1/2+i-0.01, linewidth=1, color ='black')

# %% [markdown]
# # Verify Results

# %% [markdown]
# ## Verify the Structure Constants Produce an Algebra (for $n_{gen}>1$)

# %%
if include_sc and n_gen>1:
    if n_gen==3:
        X = torch.tensor(struc_pred.numpy())
        struc_cyclic = X
        struc_cyclic[1] = -X[1]

    comm_index = 0
    Cs = []
    for i,G in enumerate(gens_pred):
        for j,H in enumerate(gens_pred):
            if i<j and n_gen!=3:
                C1 = bracket(G,H)
                C2 = 0
                for k,K in enumerate(gens_pred):
                    C2 += struc_pred[comm_index,k]*K
                C = C1 - C2
                error = torch.mean(torch.abs(C))
                print(str(i+1)+str(j+1)+': \n Structure Constants = '+str(struc_pred[comm_index,:].detach().numpy())+'\n \n C = \n ',C.detach().numpy(),'\n')
                if error<1e-1:
                    print(f'The structure constants were found successfully with a mean absolute error (MAE) of {error}. \n \n')
                elif error>1e-1:
                    print(f'The structure constants were NOT found successfully with a mean absolute error (MAE) of {error}. \n \n')
                Cs.append(C)
                comm_index+=1
            # Make the cyclic commutators if n_gen = 3   
            elif i<j and n_gen==3:
                if (j-i)==2:
                    C1 = bracket(H,G)
                    C2 = 0
                    for k,K in enumerate(gens_pred):
                        C2 += struc_cyclic[comm_index,k]*K
                    C = C1 - C2
                    error = torch.mean(torch.abs(C))
                    print(str(j+1)+str(i+1)+': \n Structure Constants = '+str(struc_cyclic[comm_index,:].detach().numpy())+'\n \n C = \n ',C.detach().numpy(),'\n')
                    if error<1e-1:
                        print(f'The structure constants were found successfully with a mean absolute error (MAE) of {error}. \n \n')
                    elif error>1e-1:
                        print(f'The structure constants were NOT found successfully with a mean absolute error (MAE) of {error}. \n \n') 
                    Cs.append(C)
                    comm_index+=1
                else:
                    C1 = bracket(G,H)
                    C2 = 0
                    for k,K in enumerate(gens_pred):
                        C2 += struc_cyclic[comm_index,k]*K
                    C = C1 - C2
                    error = torch.mean(torch.abs(C))
                    print(str(i+1)+str(j+1)+': \n Structure Constants = '+str(struc_cyclic[comm_index,:].detach().numpy())+'\n \n C = \n ',C.detach().numpy(),'\n')
                    if error<1e-1:
                        print(f'The structure constants were found successfully with a mean absolute error (MAE) of {error}. \n \n')
                    elif error>1e-1:
                        print(f'The structure constants were NOT found successfully with a mean absolute error (MAE) of {error}. \n \n') 
                    Cs.append(C)
                    comm_index+=1
    
    
    # Calculate the total MSE in finding the structure constants
    tot_error = 0.
    for i,C in enumerate(Cs):
        tot_error+=torch.mean(torch.abs(C))
    print(f'Total MAE = {tot_error}')
    # if error < 1e-1:
    #     print(f'The structure constants were found successfully with a mean absolute error (MAE) of {error}.')
    # else:
    #     print(f'The structure constants were NOT found successfully with a mean absolute error (MAE) of {error}.')

# %% [markdown]
# ## Verify Orthogonality (for $n_{gen}>1$)

# %%
def get_angle(v, w):
    # Angle between vectors
    return np.arccos( (v @ w.conj()).real / ( torch.norm(v.abs()) * torch.norm(w.abs()) ) )

def get_axis(M):
    # Finds the eigenvector with min(Imaginary(eigenvalue))
    # if the matrix is a rotation matrix or a generator of rotation,s then this vector is the axis of rotation  
    eig_vals, eig_vecs = torch.linalg.eig(M)
    # find the minimum arg of the minimum imaginary component
    # pass that to the transposed eigenvector array to pull the eigenvector
    axis = eig_vecs.T[torch.argmin(torch.abs(eig_vals.imag))]
    # Change to more positive than negative values in axis vector by multiplying by the net sign
    return torch.sign(torch.sum(axis).real)*axis

# %%
for i,G in enumerate(gens_pred):
    for j,H in enumerate(gens_pred):
        if i<j:
            angle = get_angle(get_axis(G), get_axis(H))
            angle_deg = 180/np.pi*float(angle)
            print(f'Angle between generator {i+1} and {j+1}: {angle:>.10f} rad, {angle_deg:>.10f} deg')
# Out:
# Angle between generator 1 and 2: 1.9463902712 rad, 111.5199478243 deg
# Angle between generator 1 and 3: 1.5889390707 rad, 91.0395026546 deg
# Angle between generator 1 and 4: 1.9302749634 rad, 110.5966087014 deg
# Angle between generator 1 and 5: 1.7528717518 rad, 100.4321534050 deg
# Angle between generator 1 and 6: 0.9100350738 rad, 52.1411689352 deg
# Angle between generator 1 and 7: 1.8204935789 rad, 104.3065987023 deg
# Angle between generator 1 and 8: 1.9839560986 rad, 113.6723111865 deg
# Angle between generator 1 and 9: 1.3913391829 rad, 79.7178630487 deg
# Angle between generator 1 and 10: 1.9141893387 rad, 109.6749702955 deg
# Angle between generator 1 and 11: 1.3504195213 rad, 77.3733391444 deg
# Angle between generator 1 and 12: 1.8918161392 rad, 108.3930803921 deg
# Angle between generator 1 and 13: 1.5683963299 rad, 89.8624903059 deg
# Angle between generator 1 and 14: 1.5671073198 rad, 89.7886354704 deg
# Angle between generator 1 and 15: 1.5416688919 rad, 88.3311209129 deg
# Angle between generator 1 and 16: 1.5619206429 rad, 89.4914607698 deg
# Angle between generator 1 and 17: 1.9929820299 rad, 114.1894589595 deg
# Angle between generator 1 and 18: 0.8984386921 rad, 51.4767452082 deg
# Angle between generator 1 and 19: 1.1484500170 rad, 65.8013389544 deg
# Angle between generator 1 and 20: 1.5393216610 rad, 88.1966344881 deg
# Angle between generator 1 and 21: 1.4834014177 rad, 84.9926405598 deg
# Angle between generator 1 and 22: 1.5514997244 rad, 88.8943861231 deg
# Angle between generator 1 and 23: 1.5244063139 rad, 87.3420480493 deg
# Angle between generator 1 and 24: 0.9618821740 rad, 55.1117889599 deg
# Angle between generator 1 and 25: 1.4867010117 rad, 85.1816933658 deg
# Angle between generator 1 and 26: 1.5502159595 rad, 88.8208318160 deg
# Angle between generator 1 and 27: 2.1621193886 rad, 123.8803157691 deg
# Angle between generator 1 and 28: 1.4589411020 rad, 83.5911677044 deg
# Angle between generator 1 and 29: 0.5269234180 rad, 30.1904879806 deg
# Angle between generator 1 and 30: 1.9527307749 rad, 111.8832319259 deg
# Angle between generator 1 and 31: 1.5685501099 rad, 89.8713012499 deg
# Angle between generator 1 and 32: 1.5630739927 rad, 89.5575428500 deg
# Angle between generator 1 and 33: 0.9372233748 rad, 53.6989438395 deg
# Angle between generator 1 and 34: 1.2497912645 rad, 71.6077647301 deg
# Angle between generator 1 and 35: 1.5989739895 rad, 91.6144611488 deg
# Angle between generator 1 and 36: 1.9434521198 rad, 111.3516041519 deg
# Angle between generator 2 and 3: 1.5708341599 rad, 90.0021676744 deg
# Angle between generator 2 and 4: 0.5571058989 rad, 31.9198167464 deg
# Angle between generator 2 and 5: 1.3032102585 rad, 74.6684476293 deg
# Angle between generator 2 and 6: 1.4195282459 rad, 81.3329773912 deg
# Angle between generator 2 and 7: 1.5638504028 rad, 89.6020278721 deg
# Angle between generator 2 and 8: 1.5707685947 rad, 89.9984110704 deg
# Angle between generator 2 and 9: 1.6440973282 rad, 94.1998380138 deg
# Angle between generator 2 and 10: 1.1784110069 rad, 67.5179772287 deg
# Angle between generator 2 and 11: 1.6119149923 rad, 92.3559259945 deg
# Angle between generator 2 and 12: 1.1513074636 rad, 65.9650585888 deg
# Angle between generator 2 and 13: 1.5726639032 rad, 90.1070042480 deg
# Angle between generator 2 and 14: 1.5736625195 rad, 90.1642207427 deg
# Angle between generator 2 and 15: 1.5706484318 rad, 89.9915262397 deg
# Angle between generator 2 and 16: 1.5708074570 rad, 90.0006377121 deg
# Angle between generator 2 and 17: 0.9493373632 rad, 54.3930242479 deg
# Angle between generator 2 and 18: 1.5707952976 rad, 89.9999410328 deg
# Angle between generator 2 and 19: 2.0944344997 rad, 120.0022573017 deg
# Angle between generator 2 and 20: 1.5980318785 rad, 91.5604821638 deg
# Angle between generator 2 and 21: 1.5636060238 rad, 89.5880259843 deg
# Angle between generator 2 and 22: 1.5708117485 rad, 90.0008835989 deg
# Angle between generator 2 and 23: 1.5435875654 rad, 88.4410528076 deg
# Angle between generator 2 and 24: 1.5718811750 rad, 90.0621572259 deg
# Angle between generator 2 and 25: 1.7323746681 rad, 99.2577570187 deg
# Angle between generator 2 and 26: 1.7757825851 rad, 101.7448474616 deg
# Angle between generator 2 and 27: 1.5707672834 rad, 89.9983359383 deg
# Angle between generator 2 and 28: 1.6623315811 rad, 95.2445837492 deg
# Angle between generator 2 and 29: 1.5878472328 rad, 90.9769449520 deg
# Angle between generator 2 and 30: 1.0471841097 rad, 59.9992298583 deg
# Angle between generator 2 and 31: 1.5823022127 rad, 90.6592387028 deg
# Angle between generator 2 and 32: 1.5707542896 rad, 89.9975914477 deg
# Angle between generator 2 and 33: 1.4370434284 rad, 82.3365234255 deg
# Angle between generator 2 and 34: 1.3409978151 rad, 76.8335151433 deg
# Angle between generator 2 and 35: 1.5707362890 rad, 89.9965600891 deg
# Angle between generator 2 and 36: 1.0469202995 rad, 59.9841146496 deg
# Angle between generator 3 and 4: 1.3390195370 rad, 76.7201681541 deg
# Angle between generator 3 and 5: 1.6130726337 rad, 92.4222539615 deg
# Angle between generator 3 and 6: 1.6499023438 rad, 94.5324409056 deg
# Angle between generator 3 and 7: 0.8481287360 rad, 48.5941970577 deg
# Angle between generator 3 and 8: 1.5707600117 rad, 89.9979192968 deg
# Angle between generator 3 and 9: 1.6414186954 rad, 94.0463636631 deg
# Angle between generator 3 and 10: 0.9694926143 rad, 55.5478350667 deg
# Angle between generator 3 and 11: 1.0928567648 rad, 62.6160802350 deg
# Angle between generator 3 and 12: 1.6219687462 rad, 92.9319636585 deg
# Angle between generator 3 and 13: 1.6257225275 rad, 93.1470394853 deg
# Angle between generator 3 and 14: 0.7855393291 rad, 45.0080881962 deg
# Angle between generator 3 and 15: 1.0470020771 rad, 59.9888001594 deg
# Angle between generator 3 and 16: 1.5707679987 rad, 89.9983769195 deg
# Angle between generator 3 and 17: 1.5707728863 rad, 89.9986569572 deg
# Angle between generator 3 and 18: 2.0943999290 rad, 120.0002765469 deg
# Angle between generator 3 and 19: 1.5707912445 rad, 89.9997088063 deg
# Angle between generator 3 and 20: 1.5667307377 rad, 89.7670589028 deg
# Angle between generator 3 and 21: 1.6140289307 rad, 92.4770457391 deg
# Angle between generator 3 and 22: 2.0943739414 rad, 119.9987875656 deg
# Angle between generator 3 and 23: 1.5723122358 rad, 90.0868551900 deg
# Angle between generator 3 and 24: 1.7057948112 rad, 97.7348433999 deg
# Angle between generator 3 and 25: 1.1036868095 rad, 63.2365960909 deg
# Angle between generator 3 and 26: 1.0009710789 rad, 57.3514182341 deg
# Angle between generator 3 and 27: 1.5707955360 rad, 89.9999546932 deg
# Angle between generator 3 and 28: 1.5672869682 rad, 89.7989285655 deg
# Angle between generator 3 and 29: 1.5770521164 rad, 90.3584303416 deg
# Angle between generator 3 and 30: 1.5708342791 rad, 90.0021745046 deg
# Angle between generator 3 and 31: 0.7865120173 rad, 45.0638191247 deg
# Angle between generator 3 and 32: 2.0943143368 rad, 119.9953724710 deg
# Angle between generator 3 and 33: 1.6156127453 rad, 92.5677916324 deg
# Angle between generator 3 and 34: 1.3343380690 rad, 76.4519397952 deg
# Angle between generator 3 and 35: 1.5708088875 rad, 90.0007196743 deg
# Angle between generator 3 and 36: 1.5708661079 rad, 90.0039981651 deg
# Angle between generator 4 and 5: 1.3152147532 rad, 75.3562545089 deg
# Angle between generator 4 and 6: 1.4131306410 rad, 80.9664216290 deg
# Angle between generator 4 and 7: 1.2486704588 rad, 71.5435472915 deg
# Angle between generator 4 and 8: 1.2830181122 rad, 73.5115228669 deg
# Angle between generator 4 and 9: 1.3406640291 rad, 76.8143906137 deg
# Angle between generator 4 and 10: 0.9142805934 rad, 52.3844192923 deg
# Angle between generator 4 and 11: 1.6039712429 rad, 91.9007826788 deg
# Angle between generator 4 and 12: 1.2073619366 rad, 69.1767433102 deg
# Angle between generator 4 and 13: 1.5874595642 rad, 90.9547331769 deg
# Angle between generator 4 and 14: 1.2427320480 rad, 71.2033014180 deg
# Angle between generator 4 and 15: 1.3388458490 rad, 76.7102165684 deg
# Angle between generator 4 and 16: 1.3330057859 rad, 76.3756056010 deg
# Angle between generator 4 and 17: 1.0158931017 rad, 58.2063871634 deg
# Angle between generator 4 and 18: 1.5707124472 rad, 89.9951940513 deg
# Angle between generator 4 and 19: 2.0802676678 rad, 119.1905576208 deg
# Angle between generator 4 and 20: 1.2606489658 rad, 72.2298651899 deg
# Angle between generator 4 and 21: 1.5803886652 rad, 90.5496005062 deg
# Angle between generator 4 and 22: 1.5637685061 rad, 89.5973355321 deg
# Angle between generator 4 and 23: 1.7858495712 rad, 102.3216432766 deg
# Angle between generator 4 and 24: 1.4496300220 rad, 83.0576821189 deg
# Angle between generator 4 and 25: 1.6085641384 rad, 92.1639362071 deg
# Angle between generator 4 and 26: 1.5048726797 rad, 86.2228532519 deg
# Angle between generator 4 and 27: 1.5708626509 rad, 90.0038000897 deg
# Angle between generator 4 and 28: 1.6745783091 rad, 95.9462695732 deg
# Angle between generator 4 and 29: 1.5902214050 rad, 91.1129749995 deg
# Angle between generator 4 and 30: 1.3158789873 rad, 75.3943123229 deg
# Angle between generator 4 and 31: 1.2369565964 rad, 70.8723924131 deg
# Angle between generator 4 and 32: 1.5649156570 rad, 89.6630624425 deg
# Angle between generator 4 and 33: 1.3789308071 rad, 79.0069154882 deg
# Angle between generator 4 and 34: 1.5043900013 rad, 86.1951978160 deg
# Angle between generator 4 and 35: 1.5637459755 rad, 89.5960446264 deg
# Angle between generator 4 and 36: 1.0691760778 rad, 61.2592768167 deg
# Angle between generator 5 and 6: 1.4409513474 rad, 82.5604306869 deg
# Angle between generator 5 and 7: 1.6241127253 rad, 93.0548046108 deg
# Angle between generator 5 and 8: 1.5216875076 rad, 87.1862719249 deg
# Angle between generator 5 and 9: 1.6076234579 rad, 92.1100391844 deg
# Angle between generator 5 and 10: 1.3775119781 rad, 78.9256225767 deg
# Angle between generator 5 and 11: 0.9153028131 rad, 52.4429881644 deg
# Angle between generator 5 and 12: 0.4190701544 rad, 24.0109511686 deg
# Angle between generator 5 and 13: 0.4172575772 rad, 23.9070981423 deg
# Angle between generator 5 and 14: 1.6123245955 rad, 92.3793945245 deg
# Angle between generator 5 and 15: 1.5844696760 rad, 90.7834252023 deg
# Angle between generator 5 and 16: 1.5708113909 rad, 90.0008631083 deg
# Angle between generator 5 and 17: 0.6503582001 rad, 37.2627800359 deg
# Angle between generator 5 and 18: 1.5590468645 rad, 89.3268053995 deg
# Angle between generator 5 and 19: 1.7269743681 rad, 98.9483426191 deg
# Angle between generator 5 and 20: 1.5881347656 rad, 90.9934193683 deg
# Angle between generator 5 and 21: 1.4372516870 rad, 82.3484557660 deg
# Angle between generator 5 and 22: 0.8534800410 rad, 48.9008042495 deg
# Angle between generator 5 and 23: 0.8945056200 rad, 51.2513967769 deg
# Angle between generator 5 and 24: 1.6429902315 rad, 94.1364060470 deg
# Angle between generator 5 and 25: 1.5514036417 rad, 88.8888809907 deg
# Angle between generator 5 and 26: 1.5734580755 rad, 90.1525069683 deg
# Angle between generator 5 and 27: 1.4616448879 rad, 83.7460832249 deg
# Angle between generator 5 and 28: 0.9319698215 rad, 53.3979374028 deg
# Angle between generator 5 and 29: 1.5481140614 rad, 88.7004019205 deg
# Angle between generator 5 and 30: 1.3031361103 rad, 74.6641992516 deg
# Angle between generator 5 and 31: 1.6350899935 rad, 93.6837557503 deg
# Angle between generator 5 and 32: 1.5401805639 rad, 88.2458460011 deg
# Angle between generator 5 and 33: 1.5379868746 rad, 88.1201568600 deg
# Angle between generator 5 and 34: 1.3749701977 rad, 78.7799892832 deg
# Angle between generator 5 and 35: 0.8907048106 rad, 51.0336264405 deg
# Angle between generator 5 and 36: 1.9614762068 rad, 112.3843082638 deg
# Angle between generator 6 and 7: 1.8134281635 rad, 103.9017802203 deg
# Angle between generator 6 and 8: 2.0879044533 rad, 119.6281131994 deg
# Angle between generator 6 and 9: 1.5008853674 rad, 85.9943970846 deg
# Angle between generator 6 and 10: 1.4625667334 rad, 83.7989010778 deg
# Angle between generator 6 and 11: 1.4203381538 rad, 81.3793816964 deg
# Angle between generator 6 and 12: 1.3896046877 rad, 79.6184837963 deg
# Angle between generator 6 and 13: 1.5759098530 rad, 90.2929834689 deg
# Angle between generator 6 and 14: 1.5707418919 rad, 89.9968811080 deg
# Angle between generator 6 and 15: 1.3713853359 rad, 78.5745918345 deg
# Angle between generator 6 and 16: 1.5893678665 rad, 91.0640708451 deg
# Angle between generator 6 and 17: 1.2747160196 rad, 73.0358480025 deg
# Angle between generator 6 and 18: 0.7812042832 rad, 44.7597083670 deg
# Angle between generator 6 and 19: 1.7860819101 rad, 102.3349553153 deg
# Angle between generator 6 and 20: 1.6065372229 rad, 92.0478025007 deg
# Angle between generator 6 and 21: 1.5331200361 rad, 87.8413075569 deg
# Angle between generator 6 and 22: 1.4917564392 rad, 85.4713480281 deg
# Angle between generator 6 and 23: 1.4597989321 rad, 83.6403177456 deg
# Angle between generator 6 and 24: 0.9354506135 rad, 53.5973720964 deg
# Angle between generator 6 and 25: 1.7412997484 rad, 99.7691264517 deg
# Angle between generator 6 and 26: 1.3671419621 rad, 78.3314644208 deg
# Angle between generator 6 and 27: 2.2398514748 rad, 128.3340362400 deg
# Angle between generator 6 and 28: 1.4318528175 rad, 82.0391233287 deg
# Angle between generator 6 and 29: 0.4878333211 rad, 27.9507904046 deg
# Angle between generator 6 and 30: 1.3253524303 rad, 75.9371006261 deg
# Angle between generator 6 and 31: 1.5700821877 rad, 89.9590828412 deg
# Angle between generator 6 and 32: 1.5893532038 rad, 91.0632307318 deg
# Angle between generator 6 and 33: 0.4646051228 rad, 26.6199126769 deg
# Angle between generator 6 and 34: 0.9592916369 rad, 54.9633621191 deg
# Angle between generator 6 and 35: 1.7702682018 rad, 101.4288965710 deg
# Angle between generator 6 and 36: 1.3444086313 rad, 77.0289405159 deg
# Angle between generator 7 and 8: 1.4392501116 rad, 82.4629570573 deg
# Angle between generator 7 and 9: 1.6061098576 rad, 92.0233162725 deg
# Angle between generator 7 and 10: 0.6934024692 rad, 39.7290349867 deg
# Angle between generator 7 and 11: 1.6564042568 rad, 94.9049730833 deg
# Angle between generator 7 and 12: 1.5543442965 rad, 89.0573680971 deg
# Angle between generator 7 and 13: 1.6317508221 rad, 93.4924353215 deg
# Angle between generator 7 and 14: 0.3064251542 rad, 17.5568680728 deg
# Angle between generator 7 and 15: 0.8137438297 rad, 46.6240870482 deg
# Angle between generator 7 and 16: 1.5526866913 rad, 88.9623943167 deg
# Angle between generator 7 and 17: 1.5695881844 rad, 89.9307785372 deg
# Angle between generator 7 and 18: 1.7559357882 rad, 100.6077097572 deg
# Angle between generator 7 and 19: 1.6534487009 rad, 94.7356322032 deg
# Angle between generator 7 and 20: 1.5634912252 rad, 89.5814485121 deg
# Angle between generator 7 and 21: 1.7426182032 rad, 99.8446683439 deg
# Angle between generator 7 and 22: 1.5578229427 rad, 89.2566798473 deg
# Angle between generator 7 and 23: 1.5948469639 rad, 91.3779999997 deg
# Angle between generator 7 and 24: 1.9473319054 rad, 111.5738994886 deg
# Angle between generator 7 and 25: 1.2567654848 rad, 72.0073581173 deg
# Angle between generator 7 and 26: 0.7820397615 rad, 44.8075777478 deg
# Angle between generator 7 and 27: 1.4490461349 rad, 83.0242278523 deg
# Angle between generator 7 and 28: 1.5611976385 rad, 89.4500356725 deg
# Angle between generator 7 and 29: 1.8619130850 rad, 106.6797615898 deg
# Angle between generator 7 and 30: 1.5638350248 rad, 89.6011467777 deg
# Angle between generator 7 and 31: 0.3095354140 rad, 17.7350728309 deg
# Angle between generator 7 and 32: 2.3108913898 rad, 132.4043235513 deg
# Angle between generator 7 and 33: 1.7521382570 rad, 100.3901272510 deg
# Angle between generator 7 and 34: 1.7997397184 rad, 103.1174900885 deg
# Angle between generator 7 and 35: 1.5831531286 rad, 90.7079925931 deg
# Angle between generator 7 and 36: 1.5638504028 rad, 89.6020278721 deg
# Angle between generator 8 and 9: 0.7448160052 rad, 42.6748136135 deg
# Angle between generator 8 and 10: 1.5478845835 rad, 88.6872538064 deg
# Angle between generator 8 and 11: 1.6688399315 rad, 95.6174847572 deg
# Angle between generator 8 and 12: 1.6477501392 rad, 94.4091286703 deg
# Angle between generator 8 and 13: 1.5303711891 rad, 87.6838102248 deg
# Angle between generator 8 and 14: 1.5715425014 rad, 90.0427526585 deg
# Angle between generator 8 and 15: 1.6927917004 rad, 96.9898200256 deg
# Angle between generator 8 and 16: 0.8723845482 rad, 49.9839527236 deg
# Angle between generator 8 and 17: 1.6815029383 rad, 96.3430216018 deg
# Angle between generator 8 and 18: 1.9129620790 rad, 109.6046534980 deg
# Angle between generator 8 and 19: 1.5751121044 rad, 90.2472758430 deg
# Angle between generator 8 and 20: 0.5419202447 rad, 31.0497428536 deg
# Angle between generator 8 and 21: 1.5828502178 rad, 90.6906370824 deg
# Angle between generator 8 and 22: 1.5289065838 rad, 87.5998945207 deg
# Angle between generator 8 and 23: 2.2588136196 rad, 129.4204871105 deg
# Angle between generator 8 and 24: 1.8253215551 rad, 104.5832213636 deg
# Angle between generator 8 and 25: 1.5422090292 rad, 88.3620685000 deg
# Angle between generator 8 and 26: 1.7520743608 rad, 100.3864662696 deg
# Angle between generator 8 and 27: 1.2331770658 rad, 70.6558412655 deg
# Angle between generator 8 and 28: 1.6874340773 rad, 96.6828508337 deg
# Angle between generator 8 and 29: 2.0623698235 rad, 118.1650866792 deg
# Angle between generator 8 and 30: 2.2240800858 rad, 127.4304022128 deg
# Angle between generator 8 and 31: 1.5397492647 rad, 88.2211343767 deg
# Angle between generator 8 and 32: 0.9174301028 rad, 52.5648728901 deg
# Angle between generator 8 and 33: 1.8710935116 rad, 107.2057612879 deg
# Angle between generator 8 and 34: 1.8345711231 rad, 105.1131825715 deg
# Angle between generator 8 and 35: 1.4066010714 rad, 80.5923048474 deg
# Angle between generator 8 and 36: 1.6126352549 rad, 92.3971939975 deg
# Angle between generator 9 and 10: 1.7472130060 rad, 100.1079311553 deg
# Angle between generator 9 and 11: 1.6543772221 rad, 94.7888325467 deg
# Angle between generator 9 and 12: 1.7709105015 rad, 101.4656976302 deg
# Angle between generator 9 and 13: 1.5917732716 rad, 91.2018904022 deg
# Angle between generator 9 and 14: 1.5808991194 rad, 90.5788473763 deg
# Angle between generator 9 and 15: 1.5779261589 rad, 90.4085092885 deg
# Angle between generator 9 and 16: 0.4304584265 rad, 24.6634510929 deg
# Angle between generator 9 and 17: 1.7943634987 rad, 102.8094553871 deg
# Angle between generator 9 and 18: 1.4141855240 rad, 81.0268619729 deg
# Angle between generator 9 and 19: 1.4974830151 rad, 85.7994566555 deg
# Angle between generator 9 and 20: 0.4329567254 rad, 24.8065930749 deg
# Angle between generator 9 and 21: 1.5447130203 rad, 88.5055366235 deg
# Angle between generator 9 and 22: 1.5070884228 rad, 86.3498059781 deg
# Angle between generator 9 and 23: 2.2895753384 rad, 131.1830037655 deg
# Angle between generator 9 and 24: 1.3928287029 rad, 79.8032062624 deg
# Angle between generator 9 and 25: 1.6685733795 rad, 95.6022124542 deg
# Angle between generator 9 and 26: 1.6645948887 rad, 95.3742617208 deg
# Angle between generator 9 and 27: 1.6631700993 rad, 95.2926272999 deg
# Angle between generator 9 and 28: 1.5953567028 rad, 91.4072058886 deg
# Angle between generator 9 and 29: 1.4378703833 rad, 82.3839044478 deg
# Angle between generator 9 and 30: 2.3651046753 rad, 135.5105160009 deg
# Angle between generator 9 and 31: 1.5464919806 rad, 88.6074635365 deg
# Angle between generator 9 and 32: 0.8670430183 rad, 49.6779056072 deg
# Angle between generator 9 and 33: 1.3099024296 rad, 75.0518807889 deg
# Angle between generator 9 and 34: 1.5672668219 rad, 89.7977742635 deg
# Angle between generator 9 and 35: 1.5708154440 rad, 90.0010953347 deg
# Angle between generator 9 and 36: 1.6441783905 rad, 94.2044825424 deg
# Angle between generator 10 and 11: 1.5491507053 rad, 88.7597972456 deg
# Angle between generator 10 and 12: 1.2226244211 rad, 70.0512192598 deg
# Angle between generator 10 and 13: 1.5946685076 rad, 91.3677752065 deg
# Angle between generator 10 and 14: 0.6654780507 rad, 38.1290836642 deg
# Angle between generator 10 and 15: 0.9796940088 rad, 56.1323319201 deg
# Angle between generator 10 and 16: 1.7611066103 rad, 100.9039760427 deg
# Angle between generator 10 and 17: 1.0888853073 rad, 62.3885324828 deg
# Angle between generator 10 and 18: 1.6286783218 rad, 93.3163940258 deg
# Angle between generator 10 and 19: 1.9628942013 rad, 112.4655533640 deg
# Angle between generator 10 and 20: 1.5871350765 rad, 90.9361414019 deg
# Angle between generator 10 and 21: 1.6352870464 rad, 93.6950460530 deg
# Angle between generator 10 and 22: 1.5606840849 rad, 89.4206112176 deg
# Angle between generator 10 and 23: 1.5378984213 rad, 88.1150888596 deg
# Angle between generator 10 and 24: 1.8362563848 rad, 105.2097409558 deg
# Angle between generator 10 and 25: 1.3073858023 rad, 74.9076886653 deg
# Angle between generator 10 and 26: 0.9373145700 rad, 53.7041689343 deg
# Angle between generator 10 and 27: 1.5213226080 rad, 87.1653647159 deg
# Angle between generator 10 and 28: 1.6413018703 rad, 94.0396700778 deg
# Angle between generator 10 and 29: 1.6603403091 rad, 95.1304922693 deg
# Angle between generator 10 and 30: 1.1784745455 rad, 67.5216177195 deg
# Angle between generator 10 and 31: 0.6650668979 rad, 38.1055263418 deg
# Angle between generator 10 and 32: 2.1617233753 rad, 123.8576258806 deg
# Angle between generator 10 and 33: 1.5280267000 rad, 87.5494808944 deg
# Angle between generator 10 and 34: 1.4274376631 rad, 81.7861536124 deg
# Angle between generator 10 and 35: 1.5520201921 rad, 88.9242067291 deg
# Angle between generator 10 and 36: 1.1984995604 rad, 68.6689665567 deg
# Angle between generator 11 and 12: 1.1176524162 rad, 64.0367664125 deg
# Angle between generator 11 and 13: 0.8292067051 rad, 47.5100445458 deg
# Angle between generator 11 and 14: 1.5684369802 rad, 89.8648194004 deg
# Angle between generator 11 and 15: 1.4866811037 rad, 85.1805527242 deg
# Angle between generator 11 and 16: 1.6849417686 rad, 96.5400520687 deg
# Angle between generator 11 and 17: 1.2409161329 rad, 71.0992571464 deg
# Angle between generator 11 and 18: 1.8712738752 rad, 107.2160953641 deg
# Angle between generator 11 and 19: 1.4877409935 rad, 85.2412799361 deg
# Angle between generator 11 and 20: 1.5684561729 rad, 89.8659190609 deg
# Angle between generator 11 and 21: 1.5295836926 rad, 87.6386899952 deg
# Angle between generator 11 and 22: 1.5427457094 rad, 88.3928180116 deg
# Angle between generator 11 and 23: 1.0712521076 rad, 61.3782245611 deg
# Angle between generator 11 and 24: 1.4761540890 rad, 84.5773992092 deg
# Angle between generator 11 and 25: 1.3403462172 rad, 76.7961813293 deg
# Angle between generator 11 and 26: 1.4832619429 rad, 84.9846492385 deg
# Angle between generator 11 and 27: 1.6931589842 rad, 97.0108638384 deg
# Angle between generator 11 and 28: 0.9528645873 rad, 54.5951193002 deg
# Angle between generator 11 and 29: 1.3101098537 rad, 75.0637653181 deg
# Angle between generator 11 and 30: 1.6119039059 rad, 92.3552907869 deg
# Angle between generator 11 and 31: 1.5868285894 rad, 90.9185809856 deg
# Angle between generator 11 and 32: 1.5707267523 rad, 89.9960136740 deg
# Angle between generator 11 and 33: 1.4024496078 rad, 80.3544435095 deg
# Angle between generator 11 and 34: 1.1247507334 rad, 64.4434700267 deg
# Angle between generator 11 and 35: 1.1549053192 rad, 66.1712005282 deg
# Angle between generator 11 and 36: 2.1281042099 rad, 121.9313895913 deg
# Angle between generator 12 and 13: 0.6850331426 rad, 39.2495078957 deg
# Angle between generator 12 and 14: 1.5700024366 rad, 89.9545134446 deg
# Angle between generator 12 and 15: 1.6245675087 rad, 93.0808617824 deg
# Angle between generator 12 and 16: 1.6832898855 rad, 96.4454061374 deg
# Angle between generator 12 and 17: 0.3744312227 rad, 21.4533287773 deg
# Angle between generator 12 and 18: 1.5195776224 rad, 87.0653844068 deg
# Angle between generator 12 and 19: 2.0844221115 rad, 119.4285897133 deg
# Angle between generator 12 and 20: 1.7521023750 rad, 100.3880713641 deg
# Angle between generator 12 and 21: 1.6912525892 rad, 96.9016354532 deg
# Angle between generator 12 and 22: 0.9290415645 rad, 53.2301606361 deg
# Angle between generator 12 and 23: 0.8517868519 rad, 48.8037916576 deg
# Angle between generator 12 and 24: 1.6534749269 rad, 94.7371348449 deg
# Angle between generator 12 and 25: 1.8067972660 rad, 103.5218577779 deg
# Angle between generator 12 and 26: 1.5942579508 rad, 91.3442520350 deg
# Angle between generator 12 and 27: 1.6415066719 rad, 94.0514043428 deg
# Angle between generator 12 and 28: 1.1610376835 rad, 66.5225591194 deg
# Angle between generator 12 and 29: 1.5562952757 rad, 89.1691509731 deg
# Angle between generator 12 and 30: 1.0086948872 rad, 57.7939598508 deg
# Angle between generator 12 and 31: 1.5946453810 rad, 91.3664501498 deg
# Angle between generator 12 and 32: 1.6831676960 rad, 96.4384051935 deg
# Angle between generator 12 and 33: 1.4880887270 rad, 85.2612035979 deg
# Angle between generator 12 and 34: 1.3400423527 rad, 76.7787711771 deg
# Angle between generator 12 and 35: 0.9255731106 rad, 53.0314328671 deg
# Angle between generator 12 and 36: 1.6975001097 rad, 97.2595920072 deg
# Angle between generator 13 and 14: 1.6290491819 rad, 93.3376427443 deg
# Angle between generator 13 and 15: 1.6312750578 rad, 93.4651760365 deg
# Angle between generator 13 and 16: 1.5894387960 rad, 91.0681348076 deg
# Angle between generator 13 and 17: 1.0129587650 rad, 58.0382620570 deg
# Angle between generator 13 and 18: 1.5590926409 rad, 89.3294281921 deg
# Angle between generator 13 and 19: 1.5525771379 rad, 88.9561173729 deg
# Angle between generator 13 and 20: 1.5991522074 rad, 91.6246722816 deg
# Angle between generator 13 and 21: 1.5712666512 rad, 90.0269476008 deg
# Angle between generator 13 and 22: 0.7725306153 rad, 44.2627438030 deg
# Angle between generator 13 and 23: 0.8139139414 rad, 46.6338337281 deg
# Angle between generator 13 and 24: 1.6373181343 rad, 93.8114188161 deg
# Angle between generator 13 and 25: 1.5844463110 rad, 90.7820864852 deg
# Angle between generator 13 and 26: 1.6270300150 rad, 93.2219530001 deg
# Angle between generator 13 and 27: 1.5548992157 rad, 89.0891626277 deg
# Angle between generator 13 and 28: 0.8176429272 rad, 46.8474888756 deg
# Angle between generator 13 and 29: 1.5344918966 rad, 87.9199093739 deg
# Angle between generator 13 and 30: 1.5544598103 rad, 89.0639865504 deg
# Angle between generator 13 and 31: 1.6562075615 rad, 94.8937032712 deg
# Angle between generator 13 and 32: 1.5461318493 rad, 88.5868295350 deg
# Angle between generator 13 and 33: 1.5927011967 rad, 91.2550565947 deg
# Angle between generator 13 and 34: 1.5026603937 rad, 86.0960986013 deg
# Angle between generator 13 and 35: 0.7645986080 rad, 43.8082732609 deg
# Angle between generator 13 and 36: 2.3553571701 rad, 134.9520250929 deg
# Angle between generator 14 and 15: 0.7853403687 rad, 44.9966886105 deg
# Angle between generator 14 and 16: 1.5715702772 rad, 90.0443440926 deg
# Angle between generator 14 and 17: 1.5712522268 rad, 90.0261211479 deg
# Angle between generator 14 and 18: 1.5701367855 rad, 89.9622110678 deg
# Angle between generator 14 and 19: 1.5689415932 rad, 89.8937315912 deg
# Angle between generator 14 and 20: 1.5655528307 rad, 89.6995698036 deg
# Angle between generator 14 and 21: 1.6319524050 rad, 93.5039851713 deg
# Angle between generator 14 and 22: 1.5686191320 rad, 89.8752559295 deg
# Angle between generator 14 and 23: 1.5684156418 rad, 89.8635967966 deg
# Angle between generator 14 and 24: 1.7620486021 rad, 100.9579481975 deg
# Angle between generator 14 and 25: 1.1579442024 rad, 66.3453157105 deg
# Angle between generator 14 and 26: 0.7361674309 rad, 42.1792868043 deg
# Angle between generator 14 and 27: 1.5713683367 rad, 90.0327737521 deg
# Angle between generator 14 and 28: 1.5685025454 rad, 89.8685760045 deg
# Angle between generator 14 and 29: 1.5796470642 rad, 90.5071098994 deg
# Angle between generator 14 and 30: 1.5722304583 rad, 90.0821696802 deg
# Angle between generator 14 and 31: 0.0490364730 rad, 2.8095829472 deg
# Angle between generator 14 and 32: 2.3567552567 rad, 135.0321295515 deg
# Angle between generator 14 and 33: 1.5707230568 rad, 89.9958019381 deg
# Angle between generator 14 and 34: 1.6358503103 rad, 93.7273186968 deg
# Angle between generator 14 and 35: 1.5686950684 rad, 89.8796067600 deg
# Angle between generator 14 and 36: 1.5747976303 rad, 90.2292578040 deg
# Angle between generator 15 and 16: 1.5709499121 rad, 90.0087997881 deg
# Angle between generator 15 and 17: 1.5706293583 rad, 89.9904334095 deg
# Angle between generator 15 and 18: 1.5710136890 rad, 90.0124539393 deg
# Angle between generator 15 and 19: 1.5708346367 rad, 90.0021949952 deg
# Angle between generator 15 and 20: 1.5595269203 rad, 89.3543105713 deg
# Angle between generator 15 and 21: 1.6138856411 rad, 92.4688358517 deg
# Angle between generator 15 and 22: 1.5708876848 rad, 90.0052344294 deg
# Angle between generator 15 and 23: 1.5701899529 rad, 89.9652573322 deg
# Angle between generator 15 and 24: 1.7059986591 rad, 97.7465230234 deg
# Angle between generator 15 and 25: 1.2834410667 rad, 73.5357563781 deg
# Angle between generator 15 and 26: 0.3483906388 rad, 19.9613132267 deg
# Angle between generator 15 and 27: 1.5706479549 rad, 89.9914989190 deg
# Angle between generator 15 and 28: 1.0605040789 rad, 60.7624078754 deg
# Angle between generator 15 and 29: 1.5785211325 rad, 90.4425987627 deg
# Angle between generator 15 and 30: 1.5705697536 rad, 89.9870183149 deg
# Angle between generator 15 and 31: 0.7866151333 rad, 45.0697272384 deg
# Angle between generator 15 and 32: 2.0946860313 rad, 120.0166690009 deg
# Angle between generator 15 and 33: 1.2590212822 rad, 72.1366057870 deg
# Angle between generator 15 and 34: 1.6165260077 rad, 92.6201177116 deg
# Angle between generator 15 and 35: 2.0943479538 rad, 119.9972985844 deg
# Angle between generator 15 and 36: 1.5707256794 rad, 89.9959522023 deg
# Angle between generator 16 and 17: 1.6813951731 rad, 96.3368471107 deg
# Angle between generator 16 and 18: 1.5707842112 rad, 89.9993058252 deg
# Angle between generator 16 and 19: 1.5708119869 rad, 90.0008972593 deg
# Angle between generator 16 and 20: 0.7867643237 rad, 45.0782752201 deg
# Angle between generator 16 and 21: 1.5366224051 rad, 88.0419785147 deg
# Angle between generator 16 and 22: 1.5708537102 rad, 90.0032878255 deg
# Angle between generator 16 and 23: 2.1177453995 rad, 121.3378734732 deg
# Angle between generator 16 and 24: 1.5044353008 rad, 86.1977932879 deg
# Angle between generator 16 and 25: 1.7250934839 rad, 98.8405758944 deg
# Angle between generator 16 and 26: 1.6355465651 rad, 93.7099153748 deg
# Angle between generator 16 and 27: 1.5707942247 rad, 89.9998795611 deg
# Angle between generator 16 and 28: 1.6029490232 rad, 91.8422138067 deg
# Angle between generator 16 and 29: 1.5710407495 rad, 90.0140043923 deg
# Angle between generator 16 and 30: 2.0943863392 rad, 119.9994979053 deg
# Angle between generator 16 and 31: 1.5441911221 rad, 88.4756340553 deg
# Angle between generator 16 and 32: 1.0471770763 rad, 59.9988268771 deg
# Angle between generator 16 and 33: 1.4403632879 rad, 82.5267373637 deg
# Angle between generator 16 and 34: 1.5707943439 rad, 89.9998863913 deg
# Angle between generator 16 and 35: 1.5708280802 rad, 90.0018193348 deg
# Angle between generator 16 and 36: 1.5708161592 rad, 90.0011363159 deg
# Angle between generator 17 and 18: 1.5532444715 rad, 88.9943527718 deg
# Angle between generator 17 and 19: 2.2014200687 rad, 126.1320788742 deg
# Angle between generator 17 and 20: 1.7546684742 rad, 100.5350980162 deg
# Angle between generator 17 and 21: 1.5844730139 rad, 90.7836164476 deg
# Angle between generator 17 and 22: 1.1865655184 rad, 67.9851963189 deg
# Angle between generator 17 and 23: 1.0467187166 rad, 59.9725647998 deg
# Angle between generator 17 and 24: 1.6078715324 rad, 92.1242528081 deg
# Angle between generator 17 and 25: 1.7628264427 rad, 101.0025151818 deg
# Angle between generator 17 and 26: 1.5410838127 rad, 88.2975983444 deg
# Angle between generator 17 and 27: 1.5882867575 rad, 91.0021278595 deg
# Angle between generator 17 and 28: 1.3271542788 rad, 76.0403389354 deg
# Angle between generator 17 and 29: 1.5470827818 rad, 88.6413139540 deg
# Angle between generator 17 and 30: 0.8004438281 rad, 45.8620530878 deg
# Angle between generator 17 and 31: 1.5886168480 rad, 91.0210406533 deg
# Angle between generator 17 and 32: 1.6776944399 rad, 96.1248107181 deg
# Angle between generator 17 and 33: 1.4246407747 rad, 81.6259037141 deg
# Angle between generator 17 and 34: 1.2428745031 rad, 71.2114634941 deg
# Angle between generator 17 and 35: 1.1864308119 rad, 67.9774782051 deg
# Angle between generator 17 and 36: 1.3538824320 rad, 77.5717493096 deg
# Angle between generator 18 and 19: 1.5707833767 rad, 89.9992580139 deg
# Angle between generator 18 and 20: 1.5706794262 rad, 89.9933020889 deg
# Angle between generator 18 and 21: 1.5519208908 rad, 88.9185171815 deg
# Angle between generator 18 and 22: 1.0471886396 rad, 59.9994894055 deg
# Angle between generator 18 and 23: 1.5067670345 rad, 86.3313917880 deg
# Angle between generator 18 and 24: 1.0792771578 rad, 61.8380260659 deg
# Angle between generator 18 and 25: 1.8061295748 rad, 103.4836018884 deg
# Angle between generator 18 and 26: 1.5865784883 rad, 90.9042512487 deg
# Angle between generator 18 and 27: 2.0943639278 rad, 119.9982138297 deg
# Angle between generator 18 and 28: 1.5743734837 rad, 90.2049559909 deg
# Angle between generator 18 and 29: 0.7874041200 rad, 45.1149328454 deg
# Angle between generator 18 and 30: 1.5708087683 rad, 90.0007128442 deg
# Angle between generator 18 and 31: 1.5707937479 rad, 89.9998522403 deg
# Angle between generator 18 and 32: 1.5707674026 rad, 89.9983427685 deg
# Angle between generator 18 and 33: 0.9112372994 rad, 52.2100513929 deg
# Angle between generator 18 and 34: 1.4414927959 rad, 82.5914534061 deg
# Angle between generator 18 and 35: 1.5707023144 rad, 89.9946134852 deg
# Angle between generator 18 and 36: 1.5708962679 rad, 90.0057262030 deg
# Angle between generator 19 and 20: 1.5570753813 rad, 89.2138477310 deg
# Angle between generator 19 and 21: 0.7901094556 rad, 45.2699371584 deg
# Angle between generator 19 and 22: 1.5707954168 rad, 89.9999478630 deg
# Angle between generator 19 and 23: 1.5989516973 rad, 91.6131839034 deg
# Angle between generator 19 and 24: 1.5707399845 rad, 89.9967718250 deg
# Angle between generator 19 and 25: 0.7419945598 rad, 42.5131566962 deg
# Angle between generator 19 and 26: 1.5360537767 rad, 88.0093985124 deg
# Angle between generator 19 and 27: 1.0472142696 rad, 60.0009578961 deg
# Angle between generator 19 and 28: 1.4504158497 rad, 83.1027067259 deg
# Angle between generator 19 and 29: 1.5603613853 rad, 89.4021218955 deg
# Angle between generator 19 and 30: 2.0944352150 rad, 120.0022982829 deg
# Angle between generator 19 and 31: 1.5699422359 rad, 89.9510641991 deg
# Angle between generator 19 and 32: 1.5707856417 rad, 89.9993877875 deg
# Angle between generator 19 and 33: 1.9260469675 rad, 110.3543623821 deg
# Angle between generator 19 and 34: 1.8006224632 rad, 103.1680676393 deg
# Angle between generator 19 and 35: 1.5709009171 rad, 90.0059925804 deg
# Angle between generator 19 and 36: 2.0946424007 rad, 120.0141691516 deg
# Angle between generator 20 and 21: 1.5815254450 rad, 90.6147331902 deg
# Angle between generator 20 and 22: 1.5708153248 rad, 90.0010885046 deg
# Angle between generator 20 and 23: 2.3988349438 rad, 137.4431180266 deg
# Angle between generator 20 and 24: 1.4860396385 rad, 85.1437994763 deg
# Angle between generator 20 and 25: 1.5724310875 rad, 90.0936648886 deg
# Angle between generator 20 and 26: 1.6536971331 rad, 94.7498663175 deg
# Angle between generator 20 and 27: 1.5843861103 rad, 90.7786372397 deg
# Angle between generator 20 and 28: 1.6027421951 rad, 91.8303634284 deg
# Angle between generator 20 and 29: 1.5700510740 rad, 89.9573001618 deg
# Angle between generator 20 and 30: 2.3940236568 rad, 137.1674515917 deg
# Angle between generator 20 and 31: 1.5275104046 rad, 87.5198993451 deg
# Angle between generator 20 and 32: 0.7924634814 rad, 45.4048129040 deg
# Angle between generator 20 and 33: 1.3826011419 rad, 79.2172101825 deg
# Angle between generator 20 and 34: 1.5747612715 rad, 90.2271745963 deg
# Angle between generator 20 and 35: 1.5782537460 rad, 90.4272786484 deg
# Angle between generator 20 and 36: 1.5980430841 rad, 91.5611242016 deg
# Angle between generator 21 and 22: 1.5884423256 rad, 91.0110412564 deg
# Angle between generator 21 and 23: 1.5923745632 rad, 91.2363418763 deg
# Angle between generator 21 and 24: 1.5275409222 rad, 87.5216478736 deg
# Angle between generator 21 and 25: 0.6772719622 rad, 38.8048250146 deg
# Angle between generator 21 and 26: 1.5558446646 rad, 89.1433328580 deg
# Angle between generator 21 and 27: 0.8161194324 rad, 46.7601990580 deg
# Angle between generator 21 and 28: 1.5829821825 rad, 90.6981981018 deg
# Angle between generator 21 and 29: 1.5539281368 rad, 89.0335239067 deg
# Angle between generator 21 and 30: 1.5761843920 rad, 90.3087133946 deg
# Angle between generator 21 and 31: 1.6299722195 rad, 93.3905288990 deg
# Angle between generator 21 and 32: 1.5221489668 rad, 87.2127115872 deg
# Angle between generator 21 and 33: 1.8582425117 rad, 106.4694532350 deg
# Angle between generator 21 and 34: 1.5599606037 rad, 89.3791587995 deg
# Angle between generator 21 and 35: 1.5884964466 rad, 91.0141421623 deg
# Angle between generator 21 and 36: 1.5530439615 rad, 88.9828643937 deg
# Angle between generator 22 and 23: 1.0756118298 rad, 61.6280182395 deg
# Angle between generator 22 and 24: 1.6328247786 rad, 93.5539684957 deg
# Angle between generator 22 and 25: 1.7385716438 rad, 99.6128175725 deg
# Angle between generator 22 and 26: 1.5864155293 rad, 90.8949143801 deg
# Angle between generator 22 and 27: 1.5707645416 rad, 89.9981788440 deg
# Angle between generator 22 and 28: 1.0558675528 rad, 60.4967544978 deg
# Angle between generator 22 and 29: 1.5461302996 rad, 88.5867407426 deg
# Angle between generator 22 and 30: 1.5707509518 rad, 89.9974002024 deg
# Angle between generator 22 and 31: 1.5872851610 rad, 90.9447406101 deg
# Angle between generator 22 and 32: 1.5708205700 rad, 90.0013890329 deg
# Angle between generator 22 and 33: 1.5259958506 rad, 87.4331217917 deg
# Angle between generator 22 and 34: 1.7927055359 rad, 102.7144611162 deg
# Angle between generator 22 and 35: 1.0472047329 rad, 60.0004114810 deg
# Angle between generator 22 and 36: 2.0941464901 rad, 119.9857555647 deg
# Angle between generator 23 and 24: 1.6442455053 rad, 94.2083279389 deg
# Angle between generator 23 and 25: 1.5894527435 rad, 91.0689339398 deg
# Angle between generator 23 and 26: 1.5023883581 rad, 86.0805121096 deg
# Angle between generator 23 and 27: 1.6342084408 rad, 93.6332465014 deg
# Angle between generator 23 and 28: 1.0500801802 rad, 60.1651624740 deg
# Angle between generator 23 and 29: 1.4589104652 rad, 83.5894123457 deg
# Angle between generator 23 and 30: 0.9911008477 rad, 56.7858956463 deg
# Angle between generator 23 and 31: 1.6140848398 rad, 92.4802490978 deg
# Angle between generator 23 and 32: 2.1182582378 rad, 121.3672569470 deg
# Angle between generator 23 and 33: 1.6273757219 rad, 93.2417605487 deg
# Angle between generator 23 and 34: 1.4470947981 rad, 82.9124244858 deg
# Angle between generator 23 and 35: 1.0778561831 rad, 61.7566102110 deg
# Angle between generator 23 and 36: 2.0333366394 rad, 116.5016077672 deg
# Angle between generator 24 and 25: 1.7418912649 rad, 99.8030178504 deg
# Angle between generator 24 and 26: 1.7205567360 rad, 98.5806393852 deg
# Angle between generator 24 and 27: 2.0624465942 rad, 118.1694853210 deg
# Angle between generator 24 and 28: 1.6364885569 rad, 93.7638875296 deg
# Angle between generator 24 and 29: 0.8422946334 rad, 48.2599275997 deg
# Angle between generator 24 and 30: 1.6371859312 rad, 93.8038441363 deg
# Angle between generator 24 and 31: 1.7593995333 rad, 100.8061677338 deg
# Angle between generator 24 and 32: 1.3683860302 rad, 78.4027442750 deg
# Angle between generator 24 and 33: 0.9842795134 rad, 56.3950619767 deg
# Angle between generator 24 and 34: 1.6211878061 rad, 92.8872190893 deg
# Angle between generator 24 and 35: 1.6326843500 rad, 93.5459225328 deg
# Angle between generator 24 and 36: 1.5090173483 rad, 86.4603252690 deg
# Angle between generator 25 and 26: 1.2122696638 rad, 69.4579353681 deg
# Angle between generator 25 and 27: 0.8731124401 rad, 50.0256578586 deg
# Angle between generator 25 and 28: 1.5278141499 rad, 87.5373026671 deg
# Angle between generator 25 and 29: 1.6704057455 rad, 95.7071992919 deg
# Angle between generator 25 and 30: 1.7323094606 rad, 99.2540209053 deg
# Angle between generator 25 and 31: 1.1579754353 rad, 66.3471052200 deg
# Angle between generator 25 and 32: 1.8580358028 rad, 106.4576096870 deg
# Angle between generator 25 and 33: 1.9636658430 rad, 112.5097651785 deg
# Angle between generator 25 and 34: 1.5957558155 rad, 91.4300733619 deg
# Angle between generator 25 and 35: 1.5708261728 rad, 90.0017100518 deg
# Angle between generator 25 and 36: 1.7324463129 rad, 99.2618619624 deg
# Angle between generator 26 and 27: 1.5253747702 rad, 87.3975365062 deg
# Angle between generator 26 and 28: 1.1612442732 rad, 66.5343958373 deg
# Angle between generator 26 and 29: 1.5795271397 rad, 90.5002387291 deg
# Angle between generator 26 and 30: 1.4953212738 rad, 85.6755980051 deg
# Angle between generator 26 and 31: 0.7358344793 rad, 42.1602100859 deg
# Angle between generator 26 and 32: 2.1999831200 rad, 126.0497477740 deg
# Angle between generator 26 and 33: 1.3500958681 rad, 77.3547951808 deg
# Angle between generator 26 and 34: 1.6050130129 rad, 91.9604717019 deg
# Angle between generator 26 and 35: 1.9999082088 rad, 114.5862997805 deg
# Angle between generator 26 and 36: 1.5602725744 rad, 89.3970334045 deg
# Angle between generator 27 and 28: 1.5669853687 rad, 89.7816481869 deg
# Angle between generator 27 and 29: 2.3645560741 rad, 135.4790834704 deg
# Angle between generator 27 and 30: 1.5707720518 rad, 89.9986091459 deg
# Angle between generator 27 and 31: 1.5699139833 rad, 89.9494454442 deg
# Angle between generator 27 and 32: 1.5708093643 rad, 90.0007469951 deg
# Angle between generator 27 and 33: 2.4743797779 rad, 141.7715181867 deg
# Angle between generator 27 and 34: 1.9920427799 rad, 114.1356438991 deg
# Angle between generator 27 and 35: 1.5708099604 rad, 90.0007811460 deg
# Angle between generator 27 and 36: 1.5707051754 rad, 89.9947774098 deg
# Angle between generator 28 and 29: 1.5422856808 rad, 88.3664603116 deg
# Angle between generator 28 and 30: 1.6550267935 rad, 94.8260502475 deg
# Angle between generator 28 and 31: 1.5897222757 rad, 91.0843769975 deg
# Angle between generator 28 and 32: 1.6028865576 rad, 91.8386347875 deg
# Angle between generator 28 and 33: 1.3083717823 rad, 74.9641811600 deg
# Angle between generator 28 and 34: 1.5622650385 rad, 89.5111931863 deg
# Angle between generator 28 and 35: 1.5633887053 rad, 89.5755745495 deg
# Angle between generator 28 and 36: 2.2295718193 rad, 127.7450553675 deg
# Angle between generator 29 and 30: 1.5876146555 rad, 90.9636192530 deg
# Angle between generator 29 and 31: 1.5814576149 rad, 90.6108468125 deg
# Angle between generator 29 and 32: 1.5640472174 rad, 89.6133045144 deg
# Angle between generator 29 and 33: 0.6430234909 rad, 36.8425321567 deg
# Angle between generator 29 and 34: 0.9596132040 rad, 54.9817865544 deg
# Angle between generator 29 and 35: 1.5447196960 rad, 88.5059191141 deg
# Angle between generator 29 and 36: 1.6133658886 rad, 92.4390562269 deg
# Angle between generator 30 and 31: 1.5973583460 rad, 91.5218915950 deg
# Angle between generator 30 and 32: 2.0943596363 rad, 119.9979679429 deg
# Angle between generator 30 and 33: 1.5706347227 rad, 89.9907407680 deg
# Angle between generator 30 and 34: 1.3409825563 rad, 76.8326408791 deg
# Angle between generator 30 and 35: 1.5706434250 rad, 89.9912393718 deg
# Angle between generator 30 and 36: 1.0469368696 rad, 59.9850640459 deg
# Angle between generator 31 and 32: 2.3181402683 rad, 132.8196536944 deg
# Angle between generator 31 and 33: 1.5643638372 rad, 89.6314454969 deg
# Angle between generator 31 and 34: 1.6350469589 rad, 93.6812900520 deg
# Angle between generator 31 and 35: 1.5871548653 rad, 90.9372752133 deg
# Angle between generator 31 and 36: 1.5543408394 rad, 89.0571700216 deg
# Angle between generator 32 and 33: 1.4404033422 rad, 82.5290323073 deg
# Angle between generator 32 and 34: 1.5249869823 rad, 87.3753179008 deg
# Angle between generator 32 and 35: 1.5707010031 rad, 89.9945383531 deg
# Angle between generator 32 and 36: 1.5707675219 rad, 89.9983495987 deg
# Angle between generator 33 and 34: 1.0486923456 rad, 60.0856454117 deg
# Angle between generator 33 and 35: 1.8827061653 rad, 107.8711173357 deg
# Angle between generator 33 and 36: 1.4402104616 rad, 82.5179810612 deg
# Angle between generator 34 and 35: 1.5107650757 rad, 86.5604626724 deg
# Angle between generator 34 and 36: 1.4020774364 rad, 80.3331196589 deg
# Angle between generator 35 and 36: 2.0940310955 rad, 119.9791439416 deg
