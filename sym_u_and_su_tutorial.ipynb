# %% [markdown]
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/royforestano/Deep_Learning_Symmetries/blob/main/sym_u_and_su_tutorial.ipynb)

# %% [markdown]
# # Discovering Sparse Representations of Lie Groups with Machine Learning - Tutorial

# %% [markdown]
# Author: Roy Forestano
#
# Date of Completion: 18 February 2023
#
# Connected to the paper on: Discovering Sparse Representations of Lie Groups with Machine Learning (arXiv:2302.05383: https://arxiv.org/abs/2302.05383)
#
# Given a dataset with dimension $N$, a neural network can be utilized to modify a random state of generators and structure constants to reproduce the proper entries corresponding to a given group, e.g. SO(N). The model takes in an array of the desired number of generators $N_{g}$ as $N \times N$ matrices and an array of the structure constants with shape $N_{brackets} \times N_{g}$. The model begins by looping over the generators applying a sequential layer to each. The second part loops over the rows of the structure constant array applying a sequential layer to each, which is a generalized modification to the code for a paper on deep learning symmetries [(Forestano et al.)](https://arxiv.org/abs/2301.05638). The model modifies these arrays to produce the desired generators and structure constants with an interconnected loss function, which now minimizes the dispersion between entries. This allows for a more simple visual verification of a group structure and its algebra by enforcing the resulting elements to be in a sparse representation, which may or may not be the canonical form.

# %% [markdown]
# ## Useful Resources

# %% [markdown]
# 1. The Quaternions and the Spaces S3, SU(2), SO(3), RP3: https://www.cis.upenn.edu/~cis5150/gma-v2-chap9.pdf
# 2. Charts on SO(3): https://en.wikipedia.org/wiki/Charts_on_SO(3)
# 3. Lie Groups as Manifolds SU(2) and Three sphere: http://mf23.web.rice.edu/LA_2_v1.4%20Lie%20groups%20as%20manifolds;%20su(2)%20and%20S3.pdf
# 4. Discrete Group: https://en.wikipedia.org/wiki/Discrete_group
# 5. Torch Complex: https://pytorch.org/docs/stable/complex_numbers.html
# 6. Data types: https://numpy.org/doc/stable/user/basics.types.html
# 7. Special Unitary Group: https://en.wikipedia.org/wiki/Special_unitary_group
# 8. Pauli Matrices and SU(2): https://en.wikipedia.org/wiki/Pauli_matrices
# 9. Gell-Mann Matrices and SU(3): https://en.wikipedia.org/wiki/Gell-Mann_matrices
# 10. Custom Activation for Complex Numbers: https://github.com/pytorch/pytorch/issues/47052
# 11. Complex Activation (Holomorphic Functions, e.g. Sigmoid): https://discuss.pytorch.org/t/complex-valued-neural-network/117090
# 12. Holomorphic Functions: https://en.wikipedia.org/wiki/Holomorphic_function
# 13. Special Unitary Groups: https://en.wikipedia.org/wiki/Special_unitary_group
# 14. ComplexPyTorch: https://github.com/wavefrontshaping/complexPyTorch
# 15. Sigmoid Activation Function: https://en.wikipedia.org/wiki/Sigmoid_function

# %% [markdown]
# ## Loss Function Description

# %% [markdown]
# There are three components to the loss function. Note $|G| = n_{gen}$.
#
# 1. ${\bf Invariance }$
#  $$\mathcal{L}_{inv} = \frac{a_{inv}}{ \epsilon^2} \sum_{j=1}^{n_{gen}} \left\{ \sum_{i=1}^{N} \left[ \phi \left[ (I+\epsilon W_j) \vec{x}_i \right] - \phi\left(\vec{x}_i \right) \right]^2 \right\}$$
# where we will use $\phi \equiv torch.norm$ here ($L^2$ norm which includes imaginary numbers), i.e.,
# $$ \phi(\vec{x}) = \sqrt{\sum_{i=1}^{n_{dim}} |x_i|^2}$$
#
#
# 2. ${\bf Normalization}$
#  $$\mathcal{L}_{norm} = a_{norm}  \sum_{i=1}^{n_{gen}} \left[\text{Tr}(W_i W_i^\dagger) - 2\right]^2$$
#  Note that  $\text{Tr}(W_i W_i^T)$ is equivalent to squaring all the elements of an array, or performing numpy multiplication of arrays in python.
#
# 3. ${\bf Orthogonality}$
#  $$\mathcal{L}_{orth} = a_{orth} \sum_{i, j = 1, i<j}^{n_{gen}} \left| \text{Tr}(W_i W_j) \right|^2$$
#
# 4. ${\bf Hermicity}$
#  $$ \mathcal{L}_{herm} = a_{unit}\sum_{k=0}^{n_{gen}} \left[ \sum_{i,j =1}^{N} \left| W_k - W_k^\dagger \right|_{ij} \right]^2 $$
#
# 5. ${ \bf Closure}$
#  $$\mathcal{L}_{clos} = a_{clos}  \sum_{i, j = 1, i<j}^{n_{gen}} \text{Tr}(C_{[ij]} C_{[ij]}^T)^2$$
#  where
#  $$C_{[ij]} = [W_i, W_j] - \sum_{k=1}^{n_{gen}} a_{[ij]k} W_k$$
#
# 6. ${ \bf Sparsity}$
#  $$\mathcal{L}_{sp} = a_{sp}   \sum_{i=0}^{n_{gen}} \sum_{l,m,n,p=0,\\ l \neq n, m \neq p}^{n_{dim}}  \left[ W_i^{lm} W_i^{np} \right]^2$$
#
# and therefore, our loss becomes
# $$\mathcal{L} = \mathcal{L}_{inv} + \mathcal{L}_{norm} + \mathcal{L}_{orth} + \mathcal{L}_{clos} + \mathcal{L}_{sp}$$

# %%
#!pip install torch

# %% [markdown]
# ## Imports

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
# %matplotlib inline
import scipy
import os
import copy
from tqdm import tqdm
from time import time

import torch
from torch import nn
from torch.utils.data import DataLoader
from torch.utils.data import Dataset
from torchvision import datasets
from torch import linalg
from torchvision.transforms import ToTensor
#from complexPyTorch.complexFunctions import complex_relu
torch.set_default_dtype(torch.float64)

plt.rcParams["font.family"] = 'sans-serif'
np.set_printoptions(formatter={'float_kind':'{:f}'.format}) 

# Get cpu or gpu device for training.
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using {device} device")
# Out:
# Using cpu device

# %% [markdown]
# ## Set Initial Conditions, Model, Optimizer, Loss, and Training Function

# %%
# Define oracles and useful definitions
def oracle_norm(data): # L^2 Norm (includes imaginary) on X: sqrt(sum(|x_i|^2))
    return torch.norm(torch.abs(data),dim=1)

def oracle_complex_norm(data): # L^2 Norm (includes imaginary) on X: sqrt(sum(|x_i|^2))
    return linalg.vector_norm(data,dim=1)
    #return torch.sum((data*data.conj()).abs(),dim=1)

def G2(data):
    return (c_tensor*torch.einsum('ij,ik,il->ijkl',data[:n//3],data[n//3:2*n//3],data[2*n//3:])).sum(dim=[1,2,3])

def bracket(M,N):
    return M@N - N@M

# %% [markdown]
# Define a custom complex activation function (as a Module subclass using nn.Module)

# %%
# Define a custom complex activation function (nn.Module)
class complex_activation(nn.Module):
    def forward(self, x):
        return nn.ReLU()(x.real) + 1.j * nn.ReLU()(x.imag)

# %% [markdown]
# Define model

# %%
# Define model
class find_generators(nn.Module):
    def __init__(self,n_dim,n_gen,n_com):
        super(find_generators,self).__init__()
       
        G = [ nn.Sequential( nn.Linear(in_features = n_dim*n_dim, out_features = n_dim*n_dim, bias = True, dtype=torch.cfloat), #torch.complex128
                             complex_activation(),
                             nn.Linear(in_features = n_dim*n_dim, out_features = n_dim*n_dim, bias = True, dtype=torch.cfloat),
                             complex_activation(),
                             nn.Linear(in_features = n_dim*n_dim, out_features = n_dim*n_dim, bias = True, dtype=torch.cfloat) )  for _ in range(n_gen)]
        
        
        self.gens = nn.ModuleList(G)
        
        if include_sc:
            C = [ nn.Sequential( nn.Linear(in_features = n_gen, out_features = n_gen, bias = True, dtype=torch.cfloat),
                             complex_activation(),
                             nn.Linear(in_features = n_gen, out_features = n_gen, bias = True, dtype=torch.cfloat),
                             complex_activation(),
                             nn.Linear(in_features = n_gen, out_features = n_gen, bias = True, dtype=torch.cfloat) ) for _ in range(n_com) ]
        
        
            self.struct_const = nn.ModuleList(C)
        
        self.n_gen = n_gen
        self.n_dim = n_dim
        self.n_com = n_com

    def forward(self, x, c):
        generators = []
        for i in range(self.n_gen):
            generators.append( ( self.gens[i](x[i].flatten()) ).reshape(self.n_dim,self.n_dim)  )
        
        structure_constants = torch.zeros((self.n_com,self.n_gen),dtype=torch.cfloat)
        
        if include_sc:
            structure_constants = torch.empty((self.n_com,self.n_gen),dtype=torch.cfloat)
            for i in range(self.n_com):
                structure_constants[i,:] = ( self.struct_const[i](c[i].flatten()) ).reshape(1,self.n_gen)

        return generators , structure_constants

# %% [markdown]
# Define the loss function

# %%
# define loss function
def loss_fn(data,
            generators,
            struc_const,
            eps,
            ainv=1., anorm=1., aorth=1., aclos=1., asp = 1. ):

    upper_elements = int(n_dim*(n_dim-1)/2)
    lossi = 0.
    lossn = 0.
    losso = 0.
    lossc = 0.
    losssp = 0.
    comm_index = 0
    struc_const = struc_const.to(device)
    indcs_upper = np.triu_indices(n_dim)
    indices_upper_offset = np.triu_indices_from(generators[0], k=1)
    indcs_lower = np.tril_indices(n_dim)
    indices_lower_offset = np.tril_indices_from(generators[0], k=1)
    identity = torch.eye(generators[0].shape[0],dtype=torch.cfloat).to(device)
    
    for i,G in enumerate(generators): 
        transform = torch.transpose((identity + 1.j*eps*G)@torch.transpose(data,dim0=1,dim1=0), dim0=1, dim1=0 )
        lossi  += torch.mean( ( oracle(transform) - oracle(data) )**2)**2/ eps**2
        #lossi  += torch.mean( ( G2(transform) - G2(data) ).abs()**2 ) / eps**2
        lossn  += ((torch.view_as_real(G).flatten()**2).sum() - 2)**2 #torch.conj(G)
        lossn  += (G-G.conj().T).abs().sum()**2

        losssp += (torch.outer(G.real.flatten(),G.real.flatten())**2 - torch.eye(G.real.flatten().shape[0])*torch.outer(G.real.flatten(),G.real.flatten())**2).sum()**2
        losssp += (torch.outer(G.imag.flatten(),G.imag.flatten())**2 - torch.eye(G.real.flatten().shape[0])*torch.outer(G.imag.flatten(),G.imag.flatten())**2).sum()**2
        
        losssp += (torch.outer(G[indcs_upper].abs(),G[indcs_upper].abs())**2 - torch.eye(G[indcs_upper].shape[0],dtype=torch.cfloat).abs()*torch.outer(G[indcs_upper].abs(),G[indcs_upper].abs())**2).sum()**2
        losssp += (torch.outer(G[indcs_lower].abs(),G[indcs_lower].abs())**2 - torch.eye(G[indcs_lower].shape[0],dtype=torch.cfloat).abs()*torch.outer(G[indcs_lower].abs(),G[indcs_lower].abs())**2).sum()**2
        losssp += (torch.outer(G.real.flatten(),G.imag.flatten())**2).sum()**2
        
        losso += ((G@G).trace().abs()-2)**2
        for j, H in enumerate(generators):
            if i < j:
                losso += (G@H).trace().abs()**2
                losso += (G*H).sum().abs()**2

                C1 = torch.view_as_real(bracket(G,H))
                C2 = 0
                for k,K in enumerate(generators):
                    C2 += struc_const[comm_index,k]*K
                C = C1-torch.view_as_real(C2)
                lossc += torch.sum(C**2)**2
                comm_index +=1
    
    components = [ ainv*lossi,  
                anorm*lossn,  
                aorth*losso,  
                aclos*lossc,
                asp*losssp ]

    L = ainv*lossi + anorm*lossn + aorth*losso + aclos*lossc + asp*losssp
    return  L.to(device), components

# %% [markdown]
# Define the training function

# %%
# Define the training function
def train(initial_matrices, 
          initial_struc_const,  
          data, 
          model, 
          loss_fn, 
          epochs, 
          optimizer, 
          eps):
    
    history = {'train_loss': [],
               'components_loss':[]} 
    
    best_val_loss = float('inf') #torch.inf #float('inf')
    start = time()
    
    ainv  = 1.
    anorm = 1.
    aorth = 10.
    aclos = 0.
    if include_sc:
        aclos = 10.
    asp   = 1e-1

    
    X = initial_matrices.to(device)
    Y = initial_struc_const.to(device)
    size = X.shape[0]
    
    for i in range(epochs):
        train_loss = 0.
        model.train()
        gens, struc_const = model(X,Y)
        
        loss, comp_loss = loss_fn( data         = data,
                        generators   = gens,
                        struc_const  = struc_const,
                        eps          = eps,
                        ainv         = ainv,
                        anorm        = anorm,
                        aorth        = aorth,
                        aclos        = aclos,
                        asp          = asp )

        # Backpropagation
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        train_loss += loss.data.item()
        comp_loss_for_epoch = []
        
        for j in range(len(comp_loss)):
            if torch.is_tensor(comp_loss[j]):
                comp_loss_for_epoch.append(comp_loss[j].data.item())
            else:
                comp_loss_for_epoch.append(comp_loss[j])
            
        history['train_loss'].append(train_loss)
        history['components_loss'].append(comp_loss_for_epoch)
        
        if i%1==0:
            print(f"Epoch {i+1}   |  Train Loss: {train_loss}",end='\r') #{train_loss:>8f}
        if i==epochs-1:
            print(f"Epoch {i+1}   |  Train Loss: {train_loss}")
    
        if train_loss*1e25 < 1:
            print()
            print('Reached Near Machine Zero')
            break
        
        if train_loss < best_val_loss:
            best_val_loss = train_loss
            best_model_wts = copy.deepcopy(model.state_dict())
            best_model = copy.deepcopy(model)
            torch.save(model.state_dict(),'best_complex_U6.pth')

    model = best_model   
    end = time()
    total_time = end-start
    print(f'Total Time: {total_time:>.8f}')
    print("Complete.")
    return {'history': history}

# %% [markdown]
# ## Set Hyperparameters and Train the Model

# %%
torch.manual_seed(0)
n       = 300 # sample size
n_dim   = 6   # dimension
n_gen   = 36  # n_gen_full = int(n_dim*(n_dim-1)/2) formula for full algebra
n_com = int(n_gen*(n_gen-1)/2) # N_g choose 2 of these
include_sc = True

data    = torch.randn(n,n_dim,dtype=torch.cfloat).to(device) #Can also use torch.complex128 # Ceate n number of n-dim vectors
initialize_matrices = torch.stack([ torch.randn(n_dim,n_dim,dtype=torch.cfloat) for i in range(n_gen) ], dim=0).to(device)
initialize_struc_const = torch.randn(n_com,n_gen,dtype=torch.cfloat).to(device)

oracle = oracle_complex_norm
eps   = 1e-3

model = find_generators(n_dim,n_gen,n_com).to(device)

if n_dim==2:
    lr=7e-2
elif n_dim==3:
    lr = 1e-2  
elif n_dim==4:
    lr = 5e-3
elif n_dim>=5:
    lr = 1e-3
    
optimizer = torch.optim.Adam(model.parameters(), lr=lr)

# %%
if n_dim==2:
    epochs = 500
elif n_dim>=3:
    epochs = 6000
    
training = train( initial_matrices    = initialize_matrices, 
                  initial_struc_const = initialize_struc_const,  
                  data                = data,
                  model               = model, 
                  loss_fn             = loss_fn,
                  epochs              = epochs,
                  optimizer           = optimizer,
                  eps                 = eps  )
# Out:
# Epoch 6000   |  Train Loss: 15.979277426272583
# Total Time: 35269.73253918
# Complete.

# %%
#model.load_state_dict(torch.load('best_complex_U6.pth',map_location=torch.device('cpu')))

# %% [markdown]
# ## Visualize the History of Training Loss

# %%
if n_gen>1:
    train_loss = np.array(training['history']['train_loss'])
    comp_loss = np.array(training['history']['components_loss'])
else:
    train_loss = np.array(training['history']['train_loss'])
    comp_loss = np.empty( ( train_loss.shape[0],len(training['history']['components_loss']) ) )
    for i,comp in enumerate(training['history']['components_loss']):
        for j,term in enumerate(comp):
            if torch.is_tensor(term) and term.requires_grad:
                comp_loss[i,j] = term.detach().numpy()
            else:
                comp_loss[i,j] = term

# %%
N=train_loss.shape[0]
plt.figure(figsize=(6,4)) #, dpi=100)
plt.plot( train_loss[:N], linewidth=1, linestyle='-',  color = 'r', label='Total')
plt.plot(comp_loss[:N,0], linewidth=1, linestyle=':',  color='b',   label='Invariance')
plt.plot(comp_loss[:N,1], linewidth=1, linestyle='--', color='g',   label='Normalization')
plt.plot(comp_loss[:N,2], linewidth=1, linestyle='-.', color='magenta', label='Orthogonality')
plt.plot(comp_loss[:N,3], linewidth=1, linestyle='-.', color='cyan', label='Closure')
plt.plot(comp_loss[:N,4], linewidth=1, linestyle='--', color='black', label='Sparsity')
plt.legend()

plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.yscale('log')
plt.title('Components of Loss')

plt.show()

# %% [markdown]
# ## Extract Results

# %%
model.eval()

with torch.no_grad():
    gens_pred, struc_pred = model(initialize_matrices,initialize_struc_const)

#np.save('SU4_16_gen.npy',np.stack([ gens_pred[i].detach().numpy() for i in range(n_gen) ], axis =0))
#np.save('SU4_16_struc.npy',struc_pred.detach().numpy())

# %% [markdown]
# # Visualize Results

# %% [markdown]
# ## View the Resulting Generator(s)

# %%
rows=6
cols=2*6
figsize=(40,12)

# Create labels for matrix rows and columns
ticks_gen_im =[]
ticks_gen_im_label = []
for i in range(n_dim):
    ticks_gen_im.append(i)
    ticks_gen_im_label.append(str(i+1))

fig,axes = plt.subplots(rows,cols,figsize=figsize)
for i,GEN in enumerate(gens_pred):
    plt.subplot(rows,cols,i*2+1)
    #if n_gen<10:
    #    print(f'Generator {i+1}: \n {GEN} \n')
    im = plt.imshow(GEN.real.detach().numpy(), cmap='RdBu', vmin=-np.sqrt(2), vmax=np.sqrt(2)) # use ax_GEN[0] with axes
    if i<9:
        plt.ylabel(r'$\mathbb{J}$'+f'$_{i+1}$',fontsize=20)
    else:
        number = str(i+1)
        plt.ylabel(r'$\mathbb{J}$'+f'$_{number[0]}$'+f'$_{number[1]}$',fontsize=20)
    if i*2<cols:
        plt.title('$\mathfrak{R}$',fontsize=20)
    if rows>1:
        if i*2>=(rows-1)*cols:
            plt.xticks(ticks=ticks_gen_im, labels=ticks_gen_im_label)
        else:
            plt.xticks([])
    else:
        plt.xticks(ticks=ticks_gen_im, labels=ticks_gen_im_label)
            
    if i%(cols/2)==0:
        plt.yticks(ticks=ticks_gen_im, labels=ticks_gen_im_label)
    else:
        plt.yticks([])
            
            
    plt.subplot(rows,cols,i*2+2)
    im = plt.imshow(GEN.imag.detach().numpy(), cmap='RdBu', vmin=-np.sqrt(2), vmax=np.sqrt(2))
    if i*2<cols:
        plt.title('$\mathfrak{I}$',fontsize=20)
#         if n_gen<7:
#             det = np.linalg.det(np.eye(GEN.shape[0]) + eps * GEN.detach().numpy()) #ax_GEN[1]
#             plt.title(f'det = {det}')
#         plt.axis('off')
    if rows>1:
        if i*2>=(rows-1)*cols:
            plt.xticks(ticks=ticks_gen_im, labels=ticks_gen_im_label)
        else:   #(rows*cols/2-rows-1):
            plt.xticks([])
    else:
        plt.xticks(ticks=ticks_gen_im, labels=ticks_gen_im_label)
    plt.yticks([])

if (len(gens_pred)%2==1 and n_dim%2==0) or (len(gens_pred)%2==0 and n_dim%2==1):
    plt.subplot(rows,cols,len(gens_pred)*2+1)
    plt.axis('off')
    plt.subplot(rows,cols,len(gens_pred)*2+2)
    plt.axis('off')
            
    plt.subplots_adjust(right=0.8)
cbar = fig.colorbar(im,ax=axes.ravel().tolist(), ticks=[-np.sqrt(2), 0, np.sqrt(2)])
cbar.ax.set_yticklabels(['-$\sqrt{2}$', '0', '$\sqrt{2}$']) 
#plt.savefig('U6_6_36_00.png',bbox_inches='tight')
#plt.savefig('SU6_6_35_00.png',bbox_inches='tight')
# Out:
# [Text(1, -1.4142135623730951, '-$\\sqrt{2}$'),
#  Text(1, 0.0, '0'),
#  Text(1, 1.4142135623730951, '$\\sqrt{2}$')]

# %% [markdown]
# ## View the Resulting Structure Constants (for $n_{gen}>1$)

# %%
if include_sc and n_gen>1:
    
    figsize=(12,30)
    
    if n_gen==3:
        X = torch.tensor(struc_pred.numpy())
        struc_cyclic = X
        struc_cyclic[1] = -X[1]
        
    commutator_labels = []
    if n_com==3:
        # Make the commutations cyclic for 3 generators
        for i in range(n_gen):
             for j in range(n_gen):
                    if i<j:
                        if (j-i)==2:
                            commutator_labels.append(str(j+1)+str(i+1))
                        else:
                            commutator_labels.append(str(i+1)+str(j+1))
    else:
        for i in range(n_gen):
            for j in range(n_gen):
                if i<j:
                    if n_gen>9:
                        if i<9 and j<9:
                            commutator_labels.append(str(0)+str(i+1)+str(0)+str(j+1))
                        elif i<9 and j>=9:
                            commutator_labels.append(str(0)+str(i+1)+str(j+1))
                        else:
                            commutator_labels.append(str(i+1)+str(j+1))
                    else:
                        commutator_labels.append(str(i+1)+str(j+1))
        
    ticks_com = []
    for i in range(n_com):
        ticks_com.append(i)

    ticks_gen = []
    generator_labels = []
    for i in range(n_gen):
        ticks_gen.append(i)
        generator_labels.append(str(i+1))
    
    fig,axes = plt.subplots(1,2,figsize=figsize)
    if n_com==3:
        plt.subplot(1,2,1)
        plt.imshow(struc_cyclic.real.detach().numpy(), cmap='RdBu', vmin=-2.,vmax=2.)#norm=mpl.colors.CenteredNorm())
        plt.xticks(ticks=ticks_gen,labels=generator_labels)
        plt.xlabel('$\mathbb{J}_\gamma$',fontsize=20)
        plt.yticks(ticks=ticks_com,labels=commutator_labels)
        plt.ylabel(r'$ [\mathbb{J}_\alpha$,$\mathbb{J}_\beta ] $',fontsize=20)
        plt.title(r'$\mathfrak{R}(a_{[\alpha\beta]\gamma})$',fontsize=20)
        
        plt.subplot(1,2,2)
        im = plt.imshow(struc_cyclic.imag.detach().numpy(), cmap='RdBu', vmin=-2.,vmax=2.)
        plt.xticks(ticks=ticks_gen,labels=generator_labels)
        plt.xlabel('$\mathbb{J}_\gamma$',fontsize=20)
        plt.yticks([])
        plt.title(r'$\mathfrak{I}(a_{[\alpha\beta]\gamma})$',fontsize=20)
        
    else:
        plt.subplot(1,2,1)
        plt.imshow(struc_pred.real.detach().numpy(), cmap='RdBu', vmin=-2.,vmax=2.)#norm=mpl.colors.CenteredNorm())
        plt.xticks(ticks=ticks_gen,labels=generator_labels)
        plt.xlabel('$\mathbb{J}_\gamma$',fontsize=20)
        plt.yticks(ticks=ticks_com,labels=commutator_labels)
        plt.ylabel(r'$ [\mathbb{J}_\alpha$,$\mathbb{J}_\beta ] $',fontsize=20)
        plt.title(r'$\mathfrak{R}(a_{[\alpha\beta]\gamma})$',fontsize=20)
        
        plt.subplot(1,2,2)
        im = plt.imshow(struc_pred.imag.detach().numpy(), cmap='RdBu', vmin=-2.,vmax=2.)
        plt.xticks(ticks=ticks_gen,labels=generator_labels)
        plt.xlabel('$\mathbb{J}_\gamma$',fontsize=20)
        plt.yticks([])
        plt.title(r'$\mathfrak{I}(a_{[\alpha\beta]\gamma})$',fontsize=20)
        
    plt.colorbar(im, ax=axes.ravel().tolist())
    
    # add grid lines
    # for i in range(n_gen-1):
    #     plt.axvline(x=1/2+i, linewidth=1, color ='black')
    # for i in range(n_com-1):
    #     plt.axhline(y=1/2+i-0.01, linewidth=1, color ='black')

# %% [markdown]
# # Verify Results

# %% [markdown]
# ## Verify the Structure Constants Produce an Algebra (for $n_{gen}>1$)

# %%
if include_sc and n_gen>1:
    if n_gen==3:
        X = torch.tensor(struc_pred.numpy())
        struc_cyclic = X
        struc_cyclic[1] = -X[1]

    comm_index = 0
    Cs = []
    for i,G in enumerate(gens_pred):
        for j,H in enumerate(gens_pred):
            if i<j and n_gen!=3:
                C1 = bracket(G,H)
                C2 = 0
                for k,K in enumerate(gens_pred):
                    C2 += struc_pred[comm_index,k]*K
                C = C1 - C2
                error = torch.mean(torch.abs(C))
                print(str(i+1)+str(j+1)+': \n Structure Constants = '+str(struc_pred[comm_index,:].detach().numpy())+'\n \n C = \n ',C.detach().numpy(),'\n')
                if error<1e-1:
                    print(f'The structure constants were found successfully with a mean absolute error (MAE) of {error}. \n \n')
                elif error>1e-1:
                    print(f'The structure constants were NOT found successfully with a mean absolute error (MAE) of {error}. \n \n')
                Cs.append(C)
                comm_index+=1
            # Make the cyclic commutators if n_gen = 3   
            elif i<j and n_gen==3:
                if (j-i)==2:
                    C1 = bracket(H,G)
                    C2 = 0
                    for k,K in enumerate(gens_pred):
                        C2 += struc_cyclic[comm_index,k]*K
                    C = C1 - C2
                    error = torch.mean(torch.abs(C))
                    print(str(j+1)+str(i+1)+': \n Structure Constants = '+str(struc_cyclic[comm_index,:].detach().numpy())+'\n \n C = \n ',C.detach().numpy(),'\n')
                    if error<1e-1:
                        print(f'The structure constants were found successfully with a mean absolute error (MAE) of {error}. \n \n')
                    elif error>1e-1:
                        print(f'The structure constants were NOT found successfully with a mean absolute error (MAE) of {error}. \n \n') 
                    Cs.append(C)
                    comm_index+=1
                else:
                    C1 = bracket(G,H)
                    C2 = 0
                    for k,K in enumerate(gens_pred):
                        C2 += struc_cyclic[comm_index,k]*K
                    C = C1 - C2
                    error = torch.mean(torch.abs(C))
                    print(str(i+1)+str(j+1)+': \n Structure Constants = '+str(struc_cyclic[comm_index,:].detach().numpy())+'\n \n C = \n ',C.detach().numpy(),'\n')
                    if error<1e-1:
                        print(f'The structure constants were found successfully with a mean absolute error (MAE) of {error}. \n \n')
                    elif error>1e-1:
                        print(f'The structure constants were NOT found successfully with a mean absolute error (MAE) of {error}. \n \n') 
                    Cs.append(C)
                    comm_index+=1
    
    
    # Calculate the total MSE in finding the structure constants
    tot_error = 0.
    for i,C in enumerate(Cs):
        tot_error+=torch.mean(torch.abs(C))
    print(f'Total MAE = {tot_error}')
    # if error < 1e-1:
    #     print(f'The structure constants were found successfully with a mean absolute error (MAE) of {error}.')
    # else:
    #     print(f'The structure constants were NOT found successfully with a mean absolute error (MAE) of {error}.')
# Out:
# 12:
#  Structure Constants = [ 2.6240945e-04-3.7559867e-04j -2.7705729e-04+1.0276139e-03j
#  -4.8837811e-04+1.1951476e-04j  2.3455918e-04-7.0407987e-05j
#   2.1305680e-04+3.1388178e-04j  3.3982098e-04-2.4254756e-02j
#  -8.6721033e-05+3.0390918e-04j  1.6425550e-04+4.3579414e-03j
#   7.9352409e-04+5.2329913e-02j -3.2432377e-04-2.3844838e-04j
#   4.7430396e-05+1.3821250e-01j  4.9637258e-04-2.3499578e-03j
#   5.6274235e-05+8.7913126e-05j -2.3755431e-04+1.3608187e-03j
#  -2.2779405e-04-1.5627147e-01j -6.5280497e-04-4.7449455e-02j
#  -1.0310486e-04-4.0512271e-03j -8.6492300e-04-7.3088273e-02j
#  -7.2239432e-05-1.1476696e-02j -4.4136494e-04+1.2933607e-01j
#  -1.0351576e-03-8.3451942e-03j -2.4081115e-04-2.4356440e-01j
#   6.0359016e-04-2.2936039e-02j  2.3023784e-04-2.0584464e-04j
#   6.8056583e-04+3.5979226e-04j  8.0304471e-04+1.8637963e-03j
#   1.1364222e-03-4.9564168e-03j  6.6785514e-04+8.2453862e-03j
#  -4.2445958e-04-9.7867688e-03j -1.5780330e-05+4.2576337e-01j
#   5.1116943e-04+7.3181465e-04j  4.2095780e-04+1.7660484e-04j
#   7.2018988e-04+4.5616925e-04j  1.9744039e-03+5.8549829e-04j
#  -3.0733645e-04-3.6562234e-04j  1.3110042e-03+2.0784549e-02j
#   8.9918077e-04+1.3172276e-01j -1.5674755e-03+3.9347716e-02j
#   8.6271763e-04+7.5653195e-04j -4.4940598e-04-6.6605397e-04j]
#
#  C =
#   [[ 1.2401940e-03+9.0827030e-04j  2.4580777e-02-2.0068861e-03j
#    2.8101057e-03+1.7803426e-04j  4.9509332e-03+3.6535930e-04j
#   -5.5405241e-03-2.0792494e-03j -1.3707578e-03-1.0178920e-03j]
#  [-2.3138165e-02-1.5208648e-03j -1.3573261e-04+3.5768040e-04j
#    1.0297983e-05-3.2010608e-04j -1.0263437e-03-2.9340063e-04j
#   -5.2839471e-03-1.5393255e-04j  3.0514523e-03-4.4668739e-04j]
#  [-3.2406338e-03-7.9761527e-04j  1.3333070e-04-2.3432447e-04j
#    1.4037841e-04+6.7880603e-05j -2.9419940e-03+8.3305326e-04j
#    1.7740477e-03+1.8317025e-03j  9.9480702e-03-1.4133385e-03j]
#  [-4.8234761e-03-3.5765677e-04j  2.4867081e-04-1.3783954e-03j
#    3.8709650e-03-2.0437906e-04j  1.0968338e-03+2.8253782e-03j
#   -1.6833181e-03-1.6564728e-03j  1.1594463e-03-1.3861633e-03j]
#  [ 4.1635670e-03+1.4611610e-03j  6.2312195e-03+1.4700610e-03j
#    9.7105338e-04+9.7578706e-04j  7.7067735e-04+3.7968921e-04j
#    7.0662593e-04-6.9824181e-04j -4.5135049e-03-2.6453444e-04j]
#  [ 1.2973249e-03-1.0242407e-03j -4.3928064e-03-8.9651253e-04j
#   -1.0428335e-02+5.0601957e-04j  4.9837958e-04+1.1935867e-03j
#    5.2277092e-04-5.3198449e-04j  8.4928534e-04+4.0138667e-04j]]
#
# The structure constants were found successfully with a mean absolute error (MAE) of 0.004160729236900806.
#
#
# Total MAE = 2.5306081771850586

# %% [markdown]
# ## Verify Orthogonality (for $n_{gen}>1$)

# %%
def get_angle(v, w):
    # Angle between vectors
    return np.arccos( (v @ w.conj()).real / ( torch.norm(v.abs()) * torch.norm(w.abs()) ) )

def get_axis(M):
    # Finds the eigenvector with min(Imaginary(eigenvalue))
    # if the matrix is a rotation matrix or a generator of rotation,s then this vector is the axis of rotation  
    eig_vals, eig_vecs = torch.linalg.eig(M)
    # find the minimum arg of the minimum imaginary component
    # pass that to the transposed eigenvector array to pull the eigenvector
    axis = eig_vecs.T[torch.argmin(torch.abs(eig_vals.imag))]
    # Change to more positive than negative values in axis vector by multiplying by the net sign
    return torch.sign(torch.sum(axis).real)*axis

# %%
for i,G in enumerate(gens_pred):
    for j,H in enumerate(gens_pred):
        if i<j:
            angle = get_angle(get_axis(G), get_axis(H))
            angle_deg = 180/np.pi*float(angle)
            print(f'Angle between generator {i+1} and {j+1}: {angle:>.10f} rad, {angle_deg:>.10f} deg')
# Out:
# Angle between generator 1 and 2: 1.6207779646 rad, 92.8637368989 deg
# Angle between generator 1 and 3: 1.7335357666 rad, 99.3242830612 deg
# Angle between generator 1 and 4: 1.4839289188 rad, 85.0228641469 deg
# Angle between generator 1 and 5: 1.5686593056 rad, 89.8775577032 deg
# Angle between generator 1 and 6: 1.8333641291 rad, 105.0440269062 deg
# Angle between generator 1 and 7: 1.5158709288 rad, 86.8530065048 deg
# Angle between generator 1 and 8: 1.3276457787 rad, 76.0684998053 deg
# Angle between generator 1 and 9: 1.3384432793 rad, 76.6871510196 deg
# Angle between generator 1 and 10: 1.5448677540 rad, 88.5144022091 deg
# Angle between generator 1 and 11: 1.3189160824 rad, 75.5683250524 deg
# Angle between generator 1 and 12: 1.5517174006 rad, 88.9068580486 deg
# Angle between generator 1 and 13: 1.7345596552 rad, 99.3829475560 deg
# Angle between generator 1 and 14: 1.7184371948 rad, 98.4591986217 deg
# Angle between generator 1 and 15: 1.1692371368 rad, 66.9923531909 deg
# Angle between generator 1 and 16: 1.8377796412 rad, 105.2970171130 deg
# Angle between generator 1 and 17: 2.0079078674 rad, 115.0446464549 deg
# Angle between generator 1 and 18: 1.8412121534 rad, 105.4936855800 deg
# Angle between generator 1 and 19: 1.5496104956 rad, 88.7861412852 deg
# Angle between generator 1 and 20: 1.3162994385 rad, 75.4184024001 deg
# Angle between generator 1 and 21: 0.9718746543 rad, 55.6843159067 deg
# Angle between generator 1 and 22: 0.7179041505 rad, 41.1328779178 deg
# Angle between generator 1 and 23: 0.9301580191 rad, 53.2941287727 deg
# Angle between generator 1 and 24: 1.2743176222 rad, 73.0130215103 deg
# Angle between generator 1 and 25: 1.5712218285 rad, 90.0243794496 deg
# Angle between generator 1 and 26: 1.3168566227 rad, 75.4503267043 deg
# Angle between generator 1 and 27: 1.5351442099 rad, 87.9572841690 deg
# Angle between generator 1 and 28: 1.0846097469 rad, 62.1435609180 deg
# Angle between generator 1 and 29: 0.9079498649 rad, 52.0216952662 deg
# Angle between generator 1 and 30: 1.4411106110 rad, 82.5695558196 deg
# Angle between generator 1 and 31: 1.4789758921 rad, 84.7390766170 deg
# Angle between generator 1 and 32: 1.5042345524 rad, 86.1862912493 deg
# Angle between generator 1 and 33: 1.6775580645 rad, 96.1169969817 deg
# Angle between generator 1 and 34: 0.9692305326 rad, 55.5328188958 deg
# Angle between generator 1 and 35: 1.4618836641 rad, 83.7597640938 deg
# Angle between generator 1 and 36: 1.5625535250 rad, 89.5277222441 deg
# Angle between generator 2 and 3: 1.0659518242 rad, 61.0745406903 deg
# Angle between generator 2 and 4: 1.4418826103 rad, 82.6137881247 deg
# Angle between generator 2 and 5: 1.3978116512 rad, 80.0887081697 deg
# Angle between generator 2 and 6: 1.6559792757 rad, 94.8806234589 deg
# Angle between generator 2 and 7: 0.4334488511 rad, 24.8347898033 deg
# Angle between generator 2 and 8: 1.1765308380 rad, 67.4102514851 deg
# Angle between generator 2 and 9: 1.4587711096 rad, 83.5814278546 deg
# Angle between generator 2 and 10: 0.8318207860 rad, 47.6598203490 deg
# Angle between generator 2 and 11: 1.5818434954 rad, 90.6329561349 deg
# Angle between generator 2 and 12: 1.8160969019 rad, 104.0546876653 deg
# Angle between generator 2 and 13: 0.4281460345 rad, 24.5309607909 deg
# Angle between generator 2 and 14: 1.2757753134 rad, 73.0965410635 deg
# Angle between generator 2 and 15: 1.5236111879 rad, 87.2964906876 deg
# Angle between generator 2 and 16: 1.7153282166 rad, 98.2810672882 deg
# Angle between generator 2 and 17: 1.6853146553 rad, 96.5614169005 deg
# Angle between generator 2 and 18: 1.6925380230 rad, 96.9752853830 deg
# Angle between generator 2 and 19: 1.3074129820 rad, 74.9092459485 deg
# Angle between generator 2 and 20: 1.6169178486 rad, 92.6425685434 deg
# Angle between generator 2 and 21: 0.9457654357 rad, 54.1883678747 deg
# Angle between generator 2 and 22: 1.4701346159 rad, 84.2325088070 deg
# Angle between generator 2 and 23: 1.6526575089 rad, 94.6903002377 deg
# Angle between generator 2 and 24: 1.5542967319 rad, 89.0546428516 deg
# Angle between generator 2 and 25: 1.2948009968 rad, 74.1866324248 deg
# Angle between generator 2 and 26: 1.5952677727 rad, 91.4021105675 deg
# Angle between generator 2 and 27: 1.5439840555 rad, 88.4637700167 deg
# Angle between generator 2 and 28: 1.6213957071 rad, 92.8991309392 deg
# Angle between generator 2 and 29: 1.4645128250 rad, 83.9104039160 deg
# Angle between generator 2 and 30: 1.2027466297 rad, 68.9123057063 deg
# Angle between generator 2 and 31: 1.4418505430 rad, 82.6119508038 deg
# Angle between generator 2 and 32: 1.5359811783 rad, 88.0052389272 deg
# Angle between generator 2 and 33: 1.4539386034 rad, 83.3045456460 deg
# Angle between generator 2 and 34: 1.6320034266 rad, 93.5069084923 deg
# Angle between generator 2 and 35: 0.2957637608 rad, 16.9460152271 deg
# Angle between generator 2 and 36: 0.2652712166 rad, 15.1989211393 deg
# Angle between generator 3 and 4: 1.6796926260 rad, 96.2392983490 deg
# Angle between generator 3 and 5: 1.4782887697 rad, 84.6997074067 deg
# Angle between generator 3 and 6: 1.4436974525 rad, 82.7177709246 deg
# Angle between generator 3 and 7: 1.3052713871 rad, 74.7865416000 deg
# Angle between generator 3 and 8: 2.2218205929 rad, 127.3009428073 deg
# Angle between generator 3 and 9: 1.3799355030 rad, 79.0644803225 deg
# Angle between generator 3 and 10: 0.9666221738 rad, 55.3833709417 deg
# Angle between generator 3 and 11: 1.5097225904 rad, 86.5007326681 deg
# Angle between generator 3 and 12: 1.1376824379 rad, 65.1844021176 deg
# Angle between generator 3 and 13: 0.6589081883 rad, 37.7526582787 deg
# Angle between generator 3 and 14: 1.9975187778 rad, 114.4493954688 deg
# Angle between generator 3 and 15: 1.6021713018 rad, 91.7976536525 deg
# Angle between generator 3 and 16: 1.4033358097 rad, 80.4052191358 deg
# Angle between generator 3 and 17: 1.4718073606 rad, 84.3283500215 deg
# Angle between generator 3 and 18: 1.4487209320 rad, 83.0055950963 deg
# Angle between generator 3 and 19: 2.0107269287 rad, 115.2061667684 deg
# Angle between generator 3 and 20: 1.5984325409 rad, 91.5834384296 deg
# Angle between generator 3 and 21: 1.0425792933 rad, 59.7353933110 deg
# Angle between generator 3 and 22: 1.6769572496 rad, 96.0825728283 deg
# Angle between generator 3 and 23: 1.5504736900 rad, 88.8355986850 deg
# Angle between generator 3 and 24: 1.5459338427 rad, 88.5754845908 deg
# Angle between generator 3 and 25: 1.9882725477 rad, 113.9196255062 deg
# Angle between generator 3 and 26: 1.5590347052 rad, 89.3261087202 deg
# Angle between generator 3 and 27: 1.3912934065 rad, 79.7152402561 deg
# Angle between generator 3 and 28: 1.5041445494 rad, 86.1811344565 deg
# Angle between generator 3 and 29: 1.6977274418 rad, 97.2726171780 deg
# Angle between generator 3 and 30: 2.2510135174 rad, 128.9735741728 deg
# Angle between generator 3 and 31: 1.4888573885 rad, 85.3052446577 deg
# Angle between generator 3 and 32: 1.5677026510 rad, 89.8227454351 deg
# Angle between generator 3 and 33: 1.9595267773 rad, 112.2726141803 deg
# Angle between generator 3 and 34: 1.6110136509 rad, 92.3042829342 deg
# Angle between generator 3 and 35: 1.1867688894 rad, 67.9968486216 deg
# Angle between generator 3 and 36: 1.2273068428 rad, 70.3195022602 deg
# Angle between generator 4 and 5: 0.2882037461 rad, 16.5128582903 deg
# Angle between generator 4 and 6: 1.5755226612 rad, 90.2707990145 deg
# Angle between generator 4 and 7: 1.4990953207 rad, 85.8918349640 deg
# Angle between generator 4 and 8: 1.3498232365 rad, 77.3391745382 deg
# Angle between generator 4 and 9: 1.6438452005 rad, 94.1853921637 deg
# Angle between generator 4 and 10: 0.8227728009 rad, 47.1414089910 deg
# Angle between generator 4 and 11: 1.5268458128 rad, 87.4818210405 deg
# Angle between generator 4 and 12: 1.0181343555 rad, 58.3348015500 deg
# Angle between generator 4 and 13: 1.4470113516 rad, 82.9076433534 deg
# Angle between generator 4 and 14: 1.5425081253 rad, 88.3792054446 deg
# Angle between generator 4 and 15: 1.0054172277 rad, 57.6061637995 deg
# Angle between generator 4 and 16: 1.6781020164 rad, 96.1481631349 deg
# Angle between generator 4 and 17: 1.5805194378 rad, 90.5570932238 deg
# Angle between generator 4 and 18: 1.5745933056 rad, 90.2175508597 deg
# Angle between generator 4 and 19: 1.4008603096 rad, 80.2633834275 deg
# Angle between generator 4 and 20: 1.5859904289 rad, 90.8705579255 deg
# Angle between generator 4 and 21: 1.6185792685 rad, 92.7377608899 deg
# Angle between generator 4 and 22: 1.4250451326 rad, 81.6490717158 deg
# Angle between generator 4 and 23: 1.6527577639 rad, 94.6960444268 deg
# Angle between generator 4 and 24: 1.4428949356 rad, 82.6717900911 deg
# Angle between generator 4 and 25: 1.4137009382 rad, 80.9990972540 deg
# Angle between generator 4 and 26: 1.3984450102 rad, 80.1249969647 deg
# Angle between generator 4 and 27: 0.4353476167 rad, 24.9435810564 deg
# Angle between generator 4 and 28: 1.4242709875 rad, 81.6047164673 deg
# Angle between generator 4 and 29: 1.3831670284 rad, 79.2496330905 deg
# Angle between generator 4 and 30: 1.4774334431 rad, 84.6507007994 deg
# Angle between generator 4 and 31: 0.2662237287 rad, 15.2534960583 deg
# Angle between generator 4 and 32: 0.8254191875 rad, 47.2930357755 deg
# Angle between generator 4 and 33: 1.4980590343 rad, 85.8324601296 deg
# Angle between generator 4 and 34: 1.5986895561 rad, 91.5981643174 deg
# Angle between generator 4 and 35: 1.2530844212 rad, 71.7964487059 deg
# Angle between generator 4 and 36: 1.4443377256 rad, 82.7544558707 deg
# Angle between generator 5 and 6: 1.5471028090 rad, 88.6424614258 deg
# Angle between generator 5 and 7: 1.4557555914 rad, 83.4086513894 deg
# Angle between generator 5 and 8: 1.5130678415 rad, 86.6924014366 deg
# Angle between generator 5 and 9: 1.7285293341 rad, 99.0374356067 deg
# Angle between generator 5 and 10: 0.6650468111 rad, 38.1043754549 deg
# Angle between generator 5 and 11: 1.6481320858 rad, 94.4310125964 deg
# Angle between generator 5 and 12: 0.8382783532 rad, 48.0298116964 deg
# Angle between generator 5 and 13: 1.3238344193 rad, 75.8501249972 deg
# Angle between generator 5 and 14: 1.5279705524 rad, 87.5462638753 deg
# Angle between generator 5 and 15: 0.9876665473 rad, 56.5891247265 deg
# Angle between generator 5 and 16: 1.6166355610 rad, 92.6263946555 deg
# Angle between generator 5 and 17: 1.5532913208 rad, 88.9970370362 deg
# Angle between generator 5 and 18: 1.5381278992 rad, 88.1282369738 deg
# Angle between generator 5 and 19: 1.5255584717 rad, 87.4080618277 deg
# Angle between generator 5 and 20: 1.4312663078 rad, 82.0055187980 deg
# Angle between generator 5 and 21: 1.5208774805 rad, 87.1398607895 deg
# Angle between generator 5 and 22: 1.5846021175 rad, 90.7910135424 deg
# Angle between generator 5 and 23: 1.6294715405 rad, 93.3618421045 deg
# Angle between generator 5 and 24: 1.5721894503 rad, 90.0798200951 deg
# Angle between generator 5 and 25: 1.5369340181 rad, 88.0598326292 deg
# Angle between generator 5 and 26: 1.5297504663 rad, 87.6482454298 deg
# Angle between generator 5 and 27: 0.2599117458 rad, 14.8918460795 deg
# Angle between generator 5 and 28: 1.5872583389 rad, 90.9432038175 deg
# Angle between generator 5 and 29: 1.5562953949 rad, 89.1691578033 deg
# Angle between generator 5 and 30: 1.6651873589 rad, 95.4082077610 deg
# Angle between generator 5 and 31: 0.1163375527 rad, 6.6656507667 deg
# Angle between generator 5 and 32: 0.8022902012 rad, 45.9678424727 deg
# Angle between generator 5 and 33: 1.5866026878 rad, 90.9056377771 deg
# Angle between generator 5 and 34: 1.5838872194 rad, 90.7500528980 deg
# Angle between generator 5 and 35: 1.2678339481 rad, 72.6415343516 deg
# Angle between generator 5 and 36: 1.4473890066 rad, 82.9292813927 deg
# Angle between generator 6 and 7: 1.8856546879 rad, 108.0400552347 deg
# Angle between generator 6 and 8: 1.7380044460 rad, 99.5803195325 deg
# Angle between generator 6 and 9: 1.4261603355 rad, 81.7129681354 deg
# Angle between generator 6 and 10: 1.5705051422 rad, 89.9833163523 deg
# Angle between generator 6 and 11: 1.7311872244 rad, 99.1897215044 deg
# Angle between generator 6 and 12: 1.5634123087 rad, 89.5769269269 deg
# Angle between generator 6 and 13: 1.5537004471 rad, 89.0204782454 deg
# Angle between generator 6 and 14: 1.6039439440 rad, 91.8992185655 deg
# Angle between generator 6 and 15: 1.7613828182 rad, 100.9198015910 deg
# Angle between generator 6 and 16: 1.0390853882 rad, 59.5352072966 deg
# Angle between generator 6 and 17: 1.1181074381 rad, 64.0628372446 deg
# Angle between generator 6 and 18: 1.0525554419 rad, 60.3069845219 deg
# Angle between generator 6 and 19: 1.5245701075 rad, 87.3514327293 deg
# Angle between generator 6 and 20: 1.5044633150 rad, 86.1993983823 deg
# Angle between generator 6 and 21: 1.5704042912 rad, 89.9775380123 deg
# Angle between generator 6 and 22: 1.4700689316 rad, 84.2287453728 deg
# Angle between generator 6 and 23: 2.0887477398 rad, 119.6764299576 deg
# Angle between generator 6 and 24: 1.5120506287 rad, 86.6341194324 deg
# Angle between generator 6 and 25: 1.6099817753 rad, 92.2451608167 deg
# Angle between generator 6 and 26: 1.5648291111 rad, 89.6581037252 deg
# Angle between generator 6 and 27: 1.5676684380 rad, 89.8207851708 deg
# Angle between generator 6 and 28: 1.4424570799 rad, 82.6467028063 deg
# Angle between generator 6 and 29: 2.0425686836 rad, 117.0305649373 deg
# Angle between generator 6 and 30: 1.8147028685 rad, 103.9748154331 deg
# Angle between generator 6 and 31: 1.5780025721 rad, 90.4128874398 deg
# Angle between generator 6 and 32: 1.6167104244 rad, 92.6306840143 deg
# Angle between generator 6 and 33: 1.1743427515 rad, 67.2848833629 deg
# Angle between generator 6 and 34: 1.6166918278 rad, 92.6296185047 deg
# Angle between generator 6 and 35: 1.6289292574 rad, 93.3307715740 deg
# Angle between generator 6 and 36: 1.5566002131 rad, 89.1866225970 deg
# Angle between generator 7 and 8: 1.0110318661 rad, 57.9278588793 deg
# Angle between generator 7 and 9: 1.6831630468 rad, 96.4381388161 deg
# Angle between generator 7 and 10: 1.0014927387 rad, 57.3813071419 deg
# Angle between generator 7 and 11: 1.7807923555 rad, 102.0318861615 deg
# Angle between generator 7 and 12: 1.8786045313 rad, 107.6361110170 deg
# Angle between generator 7 and 13: 0.7519208193 rad, 43.0818894729 deg
# Angle between generator 7 and 14: 1.0473221540 rad, 60.0071392173 deg
# Angle between generator 7 and 15: 1.4391789436 rad, 82.4588794343 deg
# Angle between generator 7 and 16: 1.9239987135 rad, 110.2370060718 deg
# Angle between generator 7 and 17: 1.9008860588 rad, 108.9127485049 deg
# Angle between generator 7 and 18: 1.9123617411 rad, 109.5702566654 deg
# Angle between generator 7 and 19: 1.2666258812 rad, 72.5723172145 deg
# Angle between generator 7 and 20: 1.4436839819 rad, 82.7169991133 deg
# Angle between generator 7 and 21: 1.0070809126 rad, 57.7014859196 deg
# Angle between generator 7 and 22: 1.6206321716 rad, 92.8553835776 deg
# Angle between generator 7 and 23: 1.6033426523 rad, 91.8647670913 deg
# Angle between generator 7 and 24: 1.7316310406 rad, 99.2151502987 deg
# Angle between generator 7 and 25: 1.2603369951 rad, 72.2119905849 deg
# Angle between generator 7 and 26: 1.7708865404 rad, 101.4643247622 deg
# Angle between generator 7 and 27: 1.6101089716 rad, 92.2524486286 deg
# Angle between generator 7 and 28: 1.8827353716 rad, 107.8727907321 deg
# Angle between generator 7 and 29: 1.4158958197 rad, 81.1248546970 deg
# Angle between generator 7 and 30: 1.0248271227 rad, 58.7182688606 deg
# Angle between generator 7 and 31: 1.4963192940 rad, 85.7327803488 deg
# Angle between generator 7 and 32: 1.5532324314 rad, 88.9936629227 deg
# Angle between generator 7 and 33: 1.4861079454 rad, 85.1477131747 deg
# Angle between generator 7 and 34: 1.5797122717 rad, 90.5108460129 deg
# Angle between generator 7 and 35: 0.5961312056 rad, 34.1558021146 deg
# Angle between generator 7 and 36: 0.5628409386 rad, 32.2484103171 deg
# Angle between generator 8 and 9: 1.6379088163 rad, 93.8452624034 deg
# Angle between generator 8 and 10: 1.5483202934 rad, 88.7122181478 deg
# Angle between generator 8 and 11: 1.6433438063 rad, 94.1566643881 deg
# Angle between generator 8 and 12: 2.2869498730 rad, 131.0325756792 deg
# Angle between generator 8 and 13: 1.5942239761 rad, 91.3423054311 deg
# Angle between generator 8 and 14: 0.7534254193 rad, 43.1680967055 deg
# Angle between generator 8 and 15: 1.4643969536 rad, 83.9037649721 deg
# Angle between generator 8 and 16: 1.8313660622 rad, 104.9295461055 deg
# Angle between generator 8 and 17: 1.7712140083 rad, 101.4830872918 deg
# Angle between generator 8 and 18: 1.7642391920 rad, 101.0834597537 deg
# Angle between generator 8 and 19: 0.8268315196 rad, 47.3739564417 deg
# Angle between generator 8 and 20: 1.4447811842 rad, 82.7798641744 deg
# Angle between generator 8 and 21: 1.4395632744 rad, 82.4808999642 deg
# Angle between generator 8 and 22: 1.2636255026 rad, 72.4004081833 deg
# Angle between generator 8 and 23: 1.5494450331 rad, 88.7766609826 deg
# Angle between generator 8 and 24: 1.5903780460 rad, 91.1219498681 deg
# Angle between generator 8 and 25: 0.8363814950 rad, 47.9211297263 deg
# Angle between generator 8 and 26: 1.6142526865 rad, 92.4898660041 deg
# Angle between generator 8 and 27: 1.7394962311 rad, 99.6657925197 deg
# Angle between generator 8 and 28: 1.6647435427 rad, 95.3827789667 deg
# Angle between generator 8 and 29: 1.3784854412 rad, 78.9813979014 deg
# Angle between generator 8 and 30: 0.2929572165 rad, 16.7852120834 deg
# Angle between generator 8 and 31: 1.5373288393 rad, 88.0824542158 deg
# Angle between generator 8 and 32: 1.5361963511 rad, 88.0175674186 deg
# Angle between generator 8 and 33: 1.0144242048 rad, 58.1222255725 deg
# Angle between generator 8 and 34: 1.4579163790 rad, 83.5324553983 deg
# Angle between generator 8 and 35: 1.0793564320 rad, 61.8425681417 deg
# Angle between generator 8 and 36: 1.0141676664 rad, 58.1075270054 deg
# Angle between generator 9 and 10: 1.5557312965 rad, 89.1368373481 deg
# Angle between generator 9 and 11: 0.6724824905 rad, 38.5304085044 deg
# Angle between generator 9 and 12: 1.6947720051 rad, 97.1032831281 deg
# Angle between generator 9 and 13: 1.4202200174 rad, 81.3726129789 deg
# Angle between generator 9 and 14: 1.9873601198 rad, 113.8673472383 deg
# Angle between generator 9 and 15: 2.0434691906 rad, 117.0821601863 deg
# Angle between generator 9 and 16: 1.7718160152 rad, 101.5175797471 deg
# Angle between generator 9 and 17: 1.1706637144 rad, 67.0740900647 deg
# Angle between generator 9 and 18: 1.0808067322 rad, 61.9256642231 deg
# Angle between generator 9 and 19: 1.8656451702 rad, 106.8935943221 deg
# Angle between generator 9 and 20: 1.9066758156 rad, 109.2444771325 deg
# Angle between generator 9 and 21: 1.3486264944 rad, 77.2706062691 deg
# Angle between generator 9 and 22: 0.9751414061 rad, 55.8714869956 deg
# Angle between generator 9 and 23: 1.4437297583 rad, 82.7196219059 deg
# Angle between generator 9 and 24: 1.2799246311 rad, 73.3342794579 deg
# Angle between generator 9 and 25: 1.1965448856 rad, 68.5569719449 deg
# Angle between generator 9 and 26: 0.7753810883 rad, 44.4260638714 deg
# Angle between generator 9 and 27: 1.7005186081 rad, 97.4325392272 deg
# Angle between generator 9 and 28: 0.8731685281 rad, 50.0288714626 deg
# Angle between generator 9 and 29: 1.2882667780 rad, 73.8122492659 deg
# Angle between generator 9 and 30: 1.6333016157 rad, 93.5812892524 deg
# Angle between generator 9 and 31: 1.6907899380 rad, 96.8751274890 deg
# Angle between generator 9 and 32: 1.3291746378 rad, 76.1560969815 deg
# Angle between generator 9 and 33: 1.4963598251 rad, 85.7351026131 deg
# Angle between generator 9 and 34: 1.0866174698 rad, 62.2585949640 deg
# Angle between generator 9 and 35: 1.3485758305 rad, 77.2677034387 deg
# Angle between generator 9 and 36: 1.3753687143 rad, 78.8028226056 deg
# Angle between generator 10 and 11: 1.5941822529 rad, 91.3399148649 deg
# Angle between generator 10 and 12: 1.0467252731 rad, 59.9729404602 deg
# Angle between generator 10 and 13: 0.6837228537 rad, 39.1744338714 deg
# Angle between generator 10 and 14: 1.5597637892 rad, 89.3678821572 deg
# Angle between generator 10 and 15: 1.1337147951 rad, 64.9570729315 deg
# Angle between generator 10 and 16: 1.6311743259 rad, 93.4594045266 deg
# Angle between generator 10 and 17: 1.6069723368 rad, 92.0727326911 deg
# Angle between generator 10 and 18: 1.5815491676 rad, 90.6160923978 deg
# Angle between generator 10 and 19: 1.5718015432 rad, 90.0575946596 deg
# Angle between generator 10 and 20: 1.4588532448 rad, 83.5861338549 deg
# Angle between generator 10 and 21: 1.0515056849 rad, 60.2468378761 deg
# Angle between generator 10 and 22: 1.5079232454 rad, 86.3976377928 deg
# Angle between generator 10 and 23: 1.5731937885 rad, 90.1373644389 deg
# Angle between generator 10 and 24: 1.5394071341 rad, 88.2015317337 deg
# Angle between generator 10 and 25: 1.5672663450 rad, 89.7977469428 deg
# Angle between generator 10 and 26: 1.5357239246 rad, 87.9904993790 deg
# Angle between generator 10 and 27: 0.7447654605 rad, 42.6719176133 deg
# Angle between generator 10 and 28: 1.5505818129 rad, 88.8417936665 deg
# Angle between generator 10 and 29: 1.5131151676 rad, 86.6951130217 deg
# Angle between generator 10 and 30: 1.6845319271 rad, 96.5165698784 deg
# Angle between generator 10 and 31: 0.6935983896 rad, 39.7402604026 deg
# Angle between generator 10 and 32: 1.0450795889 rad, 59.8786496987 deg
# Angle between generator 10 and 33: 1.6658538580 rad, 95.4463953486 deg
# Angle between generator 10 and 34: 1.5526189804 rad, 88.9585147693 deg
# Angle between generator 10 and 35: 0.7671592832 rad, 43.9549891394 deg
# Angle between generator 10 and 36: 0.9477262497 rad, 54.3007142413 deg
# Angle between generator 11 and 12: 1.6112027168 rad, 92.3151156142 deg
# Angle between generator 11 and 13: 1.5524383783 rad, 88.9481670327 deg
# Angle between generator 11 and 14: 2.0858435631 rad, 119.5100328890 deg
# Angle between generator 11 and 15: 1.6536233425 rad, 94.7456384304 deg
# Angle between generator 11 and 16: 1.9503599405 rad, 111.7473931237 deg
# Angle between generator 11 and 17: 1.2545058727 rad, 71.8778918816 deg
# Angle between generator 11 and 18: 1.5003508329 rad, 85.9637705164 deg
# Angle between generator 11 and 19: 1.5684380531 rad, 89.8648808721 deg
# Angle between generator 11 and 20: 2.0440649986 rad, 117.1162974717 deg
# Angle between generator 11 and 21: 1.5270342827 rad, 87.4926195696 deg
# Angle between generator 11 and 22: 0.9957813621 rad, 57.0540693636 deg
# Angle between generator 11 and 23: 1.2642315626 rad, 72.4351328650 deg
# Angle between generator 11 and 24: 1.0570229292 rad, 60.5629526912 deg
# Angle between generator 11 and 25: 1.1268415451 rad, 64.5632647145 deg
# Angle between generator 11 and 26: 1.0729042292 rad, 61.4728841528 deg
# Angle between generator 11 and 27: 1.5973540545 rad, 91.5216457082 deg
# Angle between generator 11 and 28: 0.7984292507 rad, 45.7466263059 deg
# Angle between generator 11 and 29: 1.1378166676 rad, 65.1920929106 deg
# Angle between generator 11 and 30: 1.6117030382 rad, 92.3437819182 deg
# Angle between generator 11 and 31: 1.5964167118 rad, 91.4679399307 deg
# Angle between generator 11 and 32: 1.1660547256 rad, 66.8100144609 deg
# Angle between generator 11 and 33: 1.7033630610 rad, 97.5955143710 deg
# Angle between generator 11 and 34: 1.0846712589 rad, 62.1470852956 deg
# Angle between generator 11 and 35: 1.4424203634 rad, 82.6445991080 deg
# Angle between generator 11 and 36: 1.5151628256 rad, 86.8124351811 deg
# Angle between generator 12 and 13: 1.4903383255 rad, 85.3900960978 deg
# Angle between generator 12 and 14: 2.0813653469 rad, 119.2534500026 deg
# Angle between generator 12 and 15: 1.1321785450 rad, 64.8690522837 deg
# Angle between generator 12 and 16: 1.5328357220 rad, 87.8250175557 deg
# Angle between generator 12 and 17: 1.5578074455 rad, 89.2557919227 deg
# Angle between generator 12 and 18: 1.5311033726 rad, 87.7257612467 deg
# Angle between generator 12 and 19: 2.0808548927 rad, 119.2242031326 deg
# Angle between generator 12 and 20: 1.4543548822 rad, 83.3283966666 deg
# Angle between generator 12 and 21: 1.5802408457 rad, 90.5411310717 deg
# Angle between generator 12 and 22: 1.7678215504 rad, 101.2887137684 deg
# Angle between generator 12 and 23: 1.5104784966 rad, 86.5440428977 deg
# Angle between generator 12 and 24: 1.5831297636 rad, 90.7066538760 deg
# Angle between generator 12 and 25: 2.0899143219 rad, 119.7432701888 deg
# Angle between generator 12 and 26: 1.5394759178 rad, 88.2054727529 deg
# Angle between generator 12 and 27: 0.5956060290 rad, 34.1257117162 deg
# Angle between generator 12 and 28: 1.5415636301 rad, 88.3250898558 deg
# Angle between generator 12 and 29: 1.5890996456 rad, 91.0487029195 deg
# Angle between generator 12 and 30: 2.4135963917 rad, 138.2888866911 deg
# Angle between generator 12 and 31: 0.7954943180 rad, 45.5784670485 deg
# Angle between generator 12 and 32: 1.0542548895 rad, 60.4043556987 deg
# Angle between generator 12 and 33: 2.0548851490 rad, 117.7362464219 deg
# Angle between generator 12 and 34: 1.5535826683 rad, 89.0137300185 deg
# Angle between generator 12 and 35: 1.7805333138 rad, 102.0170441604 deg
# Angle between generator 12 and 36: 1.9781275988 rad, 113.3383627474 deg
# Angle between generator 13 and 14: 1.5718137026 rad, 90.0582913389 deg
# Angle between generator 13 and 15: 1.5341408253 rad, 87.8997944668 deg
# Angle between generator 13 and 16: 1.5885227919 rad, 91.0156516341 deg
# Angle between generator 13 and 17: 1.5733613968 rad, 90.1469676848 deg
# Angle between generator 13 and 18: 1.5835448503 rad, 90.7304365947 deg
# Angle between generator 13 and 19: 1.5823913813 rad, 90.6643476843 deg
# Angle between generator 13 and 20: 1.6516902447 rad, 94.6348800828 deg
# Angle between generator 13 and 21: 0.9529417157 rad, 54.5995384326 deg
# Angle between generator 13 and 22: 1.5818036795 rad, 90.6306748517 deg
# Angle between generator 13 and 23: 1.6694834232 rad, 95.6543541183 deg
# Angle between generator 13 and 24: 1.5415428877 rad, 88.3239014029 deg
# Angle between generator 13 and 25: 1.5645766258 rad, 89.6436373845 deg
# Angle between generator 13 and 26: 1.5690857172 rad, 89.9019892899 deg
# Angle between generator 13 and 27: 1.3872896433 rad, 79.4858415226 deg
# Angle between generator 13 and 28: 1.5755825043 rad, 90.2742277695 deg
# Angle between generator 13 and 29: 1.5643608570 rad, 89.6312747421 deg
# Angle between generator 13 and 30: 1.6215205193 rad, 92.9062821473 deg
# Angle between generator 13 and 31: 1.3626528978 rad, 78.0742599872 deg
# Angle between generator 13 and 32: 1.4893536568 rad, 85.3336787352 deg
# Angle between generator 13 and 33: 1.6610746384 rad, 95.1725662346 deg
# Angle between generator 13 and 34: 1.6765234470 rad, 96.0577177699 deg
# Angle between generator 13 and 35: 0.5751881003 rad, 32.9558505755 deg
# Angle between generator 13 and 36: 0.6211187840 rad, 35.5874848967 deg
# Angle between generator 14 and 15: 1.5602130890 rad, 89.3936251402 deg
# Angle between generator 14 and 16: 1.6168230772 rad, 92.6371385430 deg
# Angle between generator 14 and 17: 1.5895954370 rad, 91.0771096762 deg
# Angle between generator 14 and 18: 1.5983096361 rad, 91.5763965045 deg
# Angle between generator 14 and 19: 1.0603295565 rad, 60.7524084784 deg
# Angle between generator 14 and 20: 0.9557303786 rad, 54.7593170478 deg
# Angle between generator 14 and 21: 1.4595751762 rad, 83.6274974806 deg
# Angle between generator 14 and 22: 1.8256814480 rad, 104.6038417047 deg
# Angle between generator 14 and 23: 1.5806970596 rad, 90.5672702056 deg
# Angle between generator 14 and 24: 2.0689117908 rad, 118.5399138004 deg
# Angle between generator 14 and 25: 1.0491113663 rad, 60.1096535266 deg
# Angle between generator 14 and 26: 2.0873267651 rad, 119.5950141027 deg
# Angle between generator 14 and 27: 1.7469063997 rad, 100.0903639087 deg
# Angle between generator 14 and 28: 2.3415164948 rad, 134.1590128095 deg
# Angle between generator 14 and 29: 2.0378699303 rad, 116.7613462009 deg
# Angle between generator 14 and 30: 0.8772799373 rad, 50.2644378569 deg
# Angle between generator 14 and 31: 1.6065486670 rad, 92.0484581988 deg
# Angle between generator 14 and 32: 1.5584033728 rad, 89.2899360384 deg
# Angle between generator 14 and 33: 1.0592771769 rad, 60.6921115684 deg
# Angle between generator 14 and 34: 1.4693058729 rad, 84.1850253319 deg
# Angle between generator 14 and 35: 1.3560924530 rad, 77.6983741866 deg
# Angle between generator 14 and 36: 1.1940581799 rad, 68.4144941988 deg
# Angle between generator 15 and 16: 1.7733304501 rad, 101.6043504704 deg
# Angle between generator 15 and 17: 2.1214377880 rad, 121.5494317525 deg
# Angle between generator 15 and 18: 2.1114716530 rad, 120.9784142775 deg
# Angle between generator 15 and 19: 1.2532250881 rad, 71.8045083292 deg
# Angle between generator 15 and 20: 1.3358995914 rad, 76.5414084431 deg
# Angle between generator 15 and 21: 1.3584017754 rad, 77.8306886112 deg
# Angle between generator 15 and 22: 1.4259527922 rad, 81.7010767761 deg
# Angle between generator 15 and 23: 1.4014517069 rad, 80.2972679960 deg
# Angle between generator 15 and 24: 1.3303719759 rad, 76.2246994015 deg
# Angle between generator 15 and 25: 1.6464425325 rad, 94.3342083253 deg
# Angle between generator 15 and 26: 1.9002683163 rad, 108.8773544646 deg
# Angle between generator 15 and 27: 0.9798163176 rad, 56.1393396941 deg
# Angle between generator 15 and 28: 1.5444173813 rad, 88.4885977544 deg
# Angle between generator 15 and 29: 1.3079179525 rad, 74.9381786298 deg
# Angle between generator 15 and 30: 1.5775729418 rad, 90.3882714380 deg
# Angle between generator 15 and 31: 0.9511811733 rad, 54.4986667838 deg
# Angle between generator 15 and 32: 1.1821337938 rad, 67.7312772063 deg
# Angle between generator 15 and 33: 1.7534209490 rad, 100.4636200865 deg
# Angle between generator 15 and 34: 1.4513453245 rad, 83.1559617108 deg
# Angle between generator 15 and 35: 1.4314714670 rad, 82.0172735535 deg
# Angle between generator 15 and 36: 1.5738413334 rad, 90.1744660264 deg
# Angle between generator 16 and 17: 1.3740062714 rad, 78.7247603736 deg
# Angle between generator 16 and 18: 1.0612847805 rad, 60.8071387843 deg
# Angle between generator 16 and 19: 1.6765716076 rad, 96.0604771664 deg
# Angle between generator 16 and 20: 1.4326558113 rad, 82.0851314829 deg
# Angle between generator 16 and 21: 1.5591081381 rad, 89.3303161167 deg
# Angle between generator 16 and 22: 1.5433509350 rad, 88.4274948821 deg
# Angle between generator 16 and 23: 1.5494774580 rad, 88.7785187941 deg
# Angle between generator 16 and 24: 1.5956189632 rad, 91.4222323048 deg
# Angle between generator 16 and 25: 2.1695048809 rad, 124.3034733089 deg
# Angle between generator 16 and 26: 1.5545685291 rad, 89.0702156830 deg
# Angle between generator 16 and 27: 1.6179579496 rad, 92.7021619439 deg
# Angle between generator 16 and 28: 1.5161497593 rad, 86.8689823172 deg
# Angle between generator 16 and 29: 2.1090264320 rad, 120.8383134373 deg
# Angle between generator 16 and 30: 1.9103428125 rad, 109.4545805816 deg
# Angle between generator 16 and 31: 1.6483311653 rad, 94.4424190124 deg
# Angle between generator 16 and 32: 2.1427416801 rad, 122.7700548591 deg
# Angle between generator 16 and 33: 1.3117420673 rad, 75.1572842682 deg
# Angle between generator 16 and 34: 2.0219092369 rad, 115.8468658333 deg
# Angle between generator 16 and 35: 1.7234195471 rad, 98.7446663781 deg
# Angle between generator 16 and 36: 1.6376529932 rad, 93.8306048175 deg
# Angle between generator 17 and 18: 0.9961698055 rad, 57.0763255350 deg
# Angle between generator 17 and 19: 1.6492397785 rad, 94.4944787142 deg
# Angle between generator 17 and 20: 1.5853308439 rad, 90.8327664888 deg
# Angle between generator 17 and 21: 1.7300815582 rad, 99.1263714999 deg
# Angle between generator 17 and 22: 1.6355514526 rad, 93.7101954126 deg
# Angle between generator 17 and 23: 1.6062059402 rad, 92.0288214050 deg
# Angle between generator 17 and 24: 1.4737691879 rad, 84.4407544447 deg
# Angle between generator 17 and 25: 1.2713555098 rad, 72.8433049698 deg
# Angle between generator 17 and 26: 1.4487535954 rad, 83.0074665681 deg
# Angle between generator 17 and 27: 1.5677368641 rad, 89.8247056994 deg
# Angle between generator 17 and 28: 1.5395539999 rad, 88.2099465268 deg
# Angle between generator 17 and 29: 2.0948009491 rad, 120.0232533032 deg
# Angle between generator 17 and 30: 1.8117547035 rad, 103.8058980248 deg
# Angle between generator 17 and 31: 1.5920976400 rad, 91.2204753469 deg
# Angle between generator 17 and 32: 1.2988184690 rad, 74.4168166301 deg
# Angle between generator 17 and 33: 1.3744803667 rad, 78.7519240359 deg
# Angle between generator 17 and 34: 1.3676630259 rad, 78.3613191776 deg
# Angle between generator 17 and 35: 1.6836543083 rad, 96.4662860257 deg
# Angle between generator 17 and 36: 1.6060937643 rad, 92.0223941970 deg
# Angle between generator 18 and 19: 2.1208658218 rad, 121.5166605049 deg
# Angle between generator 18 and 20: 1.4703817368 rad, 84.2466677892 deg
# Angle between generator 18 and 21: 1.5859473944 rad, 90.8680922272 deg
# Angle between generator 18 and 22: 1.5070807934 rad, 86.3493688459 deg
# Angle between generator 18 and 23: 1.6209206581 rad, 92.8719126354 deg
# Angle between generator 18 and 24: 1.5743710995 rad, 90.2048193871 deg
# Angle between generator 18 and 25: 1.5609487295 rad, 89.4357742375 deg
# Angle between generator 18 and 26: 1.0242486000 rad, 58.6851219525 deg
# Angle between generator 18 and 27: 1.5519254208 rad, 88.9187767287 deg
# Angle between generator 18 and 28: 1.4778134823 rad, 84.6724754424 deg
# Angle between generator 18 and 29: 2.0751974583 rad, 118.9000560150 deg
# Angle between generator 18 and 30: 1.8472621441 rad, 105.8403245106 deg
# Angle between generator 18 and 31: 1.5690846443 rad, 89.9019278182 deg
# Angle between generator 18 and 32: 1.5604510307 rad, 89.4072581977 deg
# Angle between generator 18 and 33: 1.2014070749 rad, 68.8355548705 deg
# Angle between generator 18 and 34: 1.5131393671 rad, 86.6964995501 deg
# Angle between generator 18 and 35: 1.6729235649 rad, 95.8514597174 deg
# Angle between generator 18 and 36: 1.6009162664 rad, 91.7257454209 deg
# Angle between generator 19 and 20: 1.5829628706 rad, 90.6970916112 deg
# Angle between generator 19 and 21: 1.5841003656 rad, 90.7622652762 deg
# Angle between generator 19 and 22: 1.3778609037 rad, 78.9456145404 deg
# Angle between generator 19 and 23: 1.6571260691 rad, 94.9463298788 deg
# Angle between generator 19 and 24: 1.5338797569 rad, 87.8848363525 deg
# Angle between generator 19 and 25: 1.0438687801 rad, 59.8092754673 deg
# Angle between generator 19 and 26: 2.0751013756 rad, 118.8945508825 deg
# Angle between generator 19 and 27: 1.6932032108 rad, 97.0133978386 deg
# Angle between generator 19 and 28: 1.5985349417 rad, 91.5893055621 deg
# Angle between generator 19 and 29: 1.5158219337 rad, 86.8501992970 deg
# Angle between generator 19 and 30: 0.8507558107 rad, 48.7447173515 deg
# Angle between generator 19 and 31: 1.5536779165 rad, 89.0191873397 deg
# Angle between generator 19 and 32: 1.5265666246 rad, 87.4658247375 deg
# Angle between generator 19 and 33: 1.2121639252 rad, 69.4518769903 deg
# Angle between generator 19 and 34: 1.5782821178 rad, 90.4289042334 deg
# Angle between generator 19 and 35: 1.2382016182 rad, 70.9437269088 deg
# Angle between generator 19 and 36: 1.1815794706 rad, 67.6995168267 deg
# Angle between generator 20 and 21: 1.0567572117 rad, 60.5477281996 deg
# Angle between generator 20 and 22: 1.6663366556 rad, 95.4740576148 deg
# Angle between generator 20 and 23: 1.1083132029 rad, 63.5016689024 deg
# Angle between generator 20 and 24: 2.0602722168 rad, 118.0449026705 deg
# Angle between generator 20 and 25: 1.5738713741 rad, 90.1761872341 deg
# Angle between generator 20 and 26: 2.0833039284 rad, 119.3645225389 deg
# Angle between generator 20 and 27: 1.4881819487 rad, 85.2665448059 deg
# Angle between generator 20 and 28: 2.1585707664 rad, 123.6769946978 deg
# Angle between generator 20 and 29: 2.1371245384 rad, 122.4482163454 deg
# Angle between generator 20 and 30: 1.6701215506 rad, 95.6909161209 deg
# Angle between generator 20 and 31: 1.4599384069 rad, 83.6483090670 deg
# Angle between generator 20 and 32: 1.4446220398 rad, 82.7707458718 deg
# Angle between generator 20 and 33: 1.4594199657 rad, 83.6186045743 deg
# Angle between generator 20 and 34: 1.0428303480 rad, 59.7497776894 deg
# Angle between generator 20 and 35: 1.6852289438 rad, 96.5565059944 deg
# Angle between generator 20 and 36: 1.5971521139 rad, 91.5100753677 deg
# Angle between generator 21 and 22: 1.0684911013 rad, 61.2200305498 deg
# Angle between generator 21 and 23: 1.0421366692 rad, 59.7100328186 deg
# Angle between generator 21 and 24: 1.5304769278 rad, 87.6898686026 deg
# Angle between generator 21 and 25: 1.5741034746 rad, 90.1894856124 deg
# Angle between generator 21 and 26: 1.5910800695 rad, 91.1621728521 deg
# Angle between generator 21 and 27: 1.5667451620 rad, 89.7678853557 deg
# Angle between generator 21 and 28: 1.4461359978 rad, 82.8574892743 deg
# Angle between generator 21 and 29: 1.5008084774 rad, 85.9899916126 deg
# Angle between generator 21 and 30: 1.6147667170 rad, 92.5193177798 deg
# Angle between generator 21 and 31: 1.5088964701 rad, 86.4533994572 deg
# Angle between generator 21 and 32: 1.5553793907 rad, 89.1166746297 deg
# Angle between generator 21 and 33: 1.6052294970 rad, 91.9728753255 deg
# Angle between generator 21 and 34: 1.0449657440 rad, 59.8721268680 deg
# Angle between generator 21 and 35: 0.9392985702 rad, 53.8178437726 deg
# Angle between generator 21 and 36: 0.9351956248 rad, 53.5827623218 deg
# Angle between generator 22 and 23: 1.1468456984 rad, 65.7094182686 deg
# Angle between generator 22 and 24: 0.9896863699 rad, 56.7048520367 deg
# Angle between generator 22 and 25: 1.3892493248 rad, 79.5981230024 deg
# Angle between generator 22 and 26: 1.0305147171 rad, 59.0441440161 deg
# Angle between generator 22 and 27: 1.6070345640 rad, 92.0762980499 deg
# Angle between generator 22 and 28: 0.6012085676 rad, 34.4467135317 deg
# Angle between generator 22 and 29: 1.0133103132 rad, 58.0584042849 deg
# Angle between generator 22 and 30: 1.3659960032 rad, 78.2658058123 deg
# Angle between generator 22 and 31: 1.5158456564 rad, 86.8515585047 deg
# Angle between generator 22 and 32: 1.5553112030 rad, 89.1127677615 deg
# Angle between generator 22 and 33: 1.4140743017 rad, 81.0204894064 deg
# Angle between generator 22 and 34: 1.1461285353 rad, 65.6683278505 deg
# Angle between generator 22 and 35: 1.2342729568 rad, 70.7186311945 deg
# Angle between generator 22 and 36: 1.3032071590 rad, 74.6682700444 deg
# Angle between generator 23 and 24: 1.4929739237 rad, 85.5411047501 deg
# Angle between generator 23 and 25: 1.6221685410 rad, 92.9434110556 deg
# Angle between generator 23 and 26: 1.5368210077 rad, 88.0533576099 deg
# Angle between generator 23 and 27: 1.6013928652 rad, 91.7530525172 deg
# Angle between generator 23 and 28: 1.4219238758 rad, 81.4702368727 deg
# Angle between generator 23 and 29: 1.4810856581 rad, 84.8599573050 deg
# Angle between generator 23 and 30: 1.6857688427 rad, 96.5874399212 deg
# Angle between generator 23 and 31: 1.5875642300 rad, 90.9607300829 deg
# Angle between generator 23 and 32: 1.5331047773 rad, 87.8404332927 deg
# Angle between generator 23 and 33: 1.6977938414 rad, 97.2764215933 deg
# Angle between generator 23 and 34: 0.9798941612 rad, 56.1437998077 deg
# Angle between generator 23 and 35: 1.6027008295 rad, 91.8279933528 deg
# Angle between generator 23 and 36: 1.6111699343 rad, 92.3132373122 deg
# Angle between generator 24 and 25: 1.5532559156 rad, 88.9950084700 deg
# Angle between generator 24 and 26: 1.0490237474 rad, 60.1046333375 deg
# Angle between generator 24 and 27: 1.5297873020 rad, 87.6503559583 deg
# Angle between generator 24 and 28: 0.8002863526 rad, 45.8530304079 deg
# Angle between generator 24 and 29: 1.0517879725 rad, 60.2630117640 deg
# Angle between generator 24 and 30: 1.5583796501 rad, 89.2885768307 deg
# Angle between generator 24 and 31: 1.5176994801 rad, 86.9577747765 deg
# Angle between generator 24 and 32: 1.5634676218 rad, 89.5800961347 deg
# Angle between generator 24 and 33: 1.5353784561 rad, 87.9707054907 deg
# Angle between generator 24 and 34: 1.5815238953 rad, 90.6146443977 deg
# Angle between generator 24 and 35: 1.3998056650 rad, 80.2029567439 deg
# Angle between generator 24 and 36: 1.4951400757 rad, 85.6652161175 deg
# Angle between generator 25 and 26: 1.5744813681 rad, 90.2111373121 deg
# Angle between generator 25 and 27: 1.7039659023 rad, 97.6300546376 deg
# Angle between generator 25 and 28: 1.6094914675 rad, 92.2170682487 deg
# Angle between generator 25 and 29: 1.5461875200 rad, 88.5900192334 deg
# Angle between generator 25 and 30: 0.8619317412 rad, 49.3850510013 deg
# Angle between generator 25 and 31: 1.5666406155 rad, 89.7618952798 deg
# Angle between generator 25 and 32: 1.0399688482 rad, 59.5858258286 deg
# Angle between generator 25 and 33: 1.1744214296 rad, 67.2893912878 deg
# Angle between generator 25 and 34: 1.0644104481 rad, 60.9862263443 deg
# Angle between generator 25 and 35: 1.2303649187 rad, 70.4947171030 deg
# Angle between generator 25 and 36: 1.1657865047 rad, 66.7946465352 deg
# Angle between generator 26 and 27: 1.4821734428 rad, 84.9222827811 deg
# Angle between generator 26 and 28: 0.8096935153 rad, 46.3920211258 deg
# Angle between generator 26 and 29: 1.0672199726 rad, 61.1472002426 deg
# Angle between generator 26 and 30: 1.5773153305 rad, 90.3735113992 deg
# Angle between generator 26 and 31: 1.4757062197 rad, 84.5517381885 deg
# Angle between generator 26 and 32: 1.5552691221 rad, 89.1103567047 deg
# Angle between generator 26 and 33: 1.4630156755 rad, 83.8246235702 deg
# Angle between generator 26 and 34: 1.5835015774 rad, 90.7279572360 deg
# Angle between generator 26 and 35: 1.4345759153 rad, 82.1951453399 deg
# Angle between generator 26 and 36: 1.5384308100 rad, 88.1455924844 deg
# Angle between generator 27 and 28: 1.5135484934 rad, 86.7199407594 deg
# Angle between generator 27 and 29: 1.4994933605 rad, 85.9146409657 deg
# Angle between generator 27 and 30: 1.8759841919 rad, 107.4859766288 deg
# Angle between generator 27 and 31: 0.2081592232 rad, 11.9266449560 deg
# Angle between generator 27 and 32: 0.8131306171 rad, 46.5889525551 deg
# Angle between generator 27 and 33: 1.7456244230 rad, 100.0169120544 deg
# Angle between generator 27 and 34: 1.5835347176 rad, 90.7298560286 deg
# Angle between generator 27 and 35: 1.4217242002 rad, 81.4587963059 deg
# Angle between generator 27 and 36: 1.6278744936 rad, 93.2703380602 deg
# Angle between generator 28 and 29: 0.8913418055 rad, 51.0701235563 deg
# Angle between generator 28 and 30: 1.6509274244 rad, 94.5911737023 deg
# Angle between generator 28 and 31: 1.5068989992 rad, 86.3389528075 deg
# Angle between generator 28 and 32: 1.5669224262 rad, 89.7780418470 deg
# Angle between generator 28 and 33: 1.6301149130 rad, 93.3987046355 deg
# Angle between generator 28 and 34: 1.4686024189 rad, 84.1447203856 deg
# Angle between generator 28 and 35: 1.3997112513 rad, 80.1975472341 deg
# Angle between generator 28 and 36: 1.5257235765 rad, 87.4175216397 deg
# Angle between generator 29 and 30: 1.2773140669 rad, 73.1847051453 deg
# Angle between generator 29 and 31: 1.4656145573 rad, 83.9735285243 deg
# Angle between generator 29 and 32: 1.5317944288 rad, 87.7653558533 deg
# Angle between generator 29 and 33: 1.8115051985 rad, 103.7916024388 deg
# Angle between generator 29 and 34: 1.5540174246 rad, 89.0386397184 deg
# Angle between generator 29 and 35: 1.3066638708 rad, 74.8663250397 deg
# Angle between generator 29 and 36: 1.4884905815 rad, 85.2842281656 deg
# Angle between generator 30 and 31: 1.6872390509 rad, 96.6716766442 deg
# Angle between generator 30 and 32: 1.6485489607 rad, 94.4548977680 deg
# Angle between generator 30 and 33: 1.0762075186 rad, 61.6621486947 deg
# Angle between generator 30 and 34: 1.6128149033 rad, 92.4074870926 deg
# Angle between generator 30 and 35: 1.1366777420 rad, 65.1268372833 deg
# Angle between generator 30 and 36: 1.0695500374 rad, 61.2807031202 deg
# Angle between generator 31 and 32: 0.7949146628 rad, 45.5452552537 deg
# Angle between generator 31 and 33: 1.6289845705 rad, 93.3339407818 deg
# Angle between generator 31 and 34: 1.5514383316 rad, 88.8908685757 deg
# Angle between generator 31 and 35: 1.2933816910 rad, 74.1053121926 deg
# Angle between generator 31 and 36: 1.4920125008 rad, 85.4860192745 deg
# Angle between generator 32 and 33: 1.6194791794 rad, 92.7893219879 deg
# Angle between generator 32 and 34: 1.0133554935 rad, 58.0609929266 deg
# Angle between generator 32 and 35: 1.4347718954 rad, 82.2063741709 deg
# Angle between generator 32 and 36: 1.5662174225 rad, 89.7376481083 deg
# Angle between generator 33 and 34: 1.5589299202 rad, 89.3201049839 deg
# Angle between generator 33 and 35: 1.4022777081 rad, 80.3445943767 deg
# Angle between generator 33 and 36: 1.2951796055 rad, 74.2083251057 deg
# Angle between generator 34 and 35: 1.5728405714 rad, 90.1171265884 deg
# Angle between generator 34 and 36: 1.5656436682 rad, 89.7047744078 deg
# Angle between generator 35 and 36: 0.2706257701 rad, 15.5057144537 deg
